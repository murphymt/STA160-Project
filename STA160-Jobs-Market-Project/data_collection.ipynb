# %%
import requests
import pandas as pd
import lxml.html as html
#import time
import re
import os
import math
import pickle

wd0 = "/Users/tmm/Documents/GitHub/STA160-Project/Working/cyber_coders/1data_collection"
os.chdir(wd0)

# %%
def shell_crawler(search, search_terms, num_pages):
    """
    (Purpose)
    Primary crawling function that search key job terms on the cybercoders webpage and extracts
    all of the job titles and their corresponding urls. This is done so that each of the listings
    on each page of the search terms are known and then helper functions may be used to crawl through
    each one and retrieve the relevant information. 
    
    (Arguments)
    search : list of broad data/statistics related search terms to request from the the main webpage
    search_terms : list of the specific terms for each search
    num_pages : list of number of pages give each search term
    
    (Returns)
    job_titles : list of the job titles corresponding to each listing of the search results
    job_links : list of the urls corresponsing to each listing of the search results
    job_type : the "statistics" related search terms that were "techinically" inputted into the cybercoder search box

    """
    
    # query each job type (data scientist, data engineer, data analyst, business intelligence, finance, product manager ), 
    # crawl through each page, extract (titles, links, search term used)
    job_type = []
    job_titles = []
    job_links = []
    total_response = []
    flattened_set = []
  
    for j in range(num_pages + 1):
        j = j + 1
        url = search + '&page=' + str(j)
        response = requests.get(url)
        response_tree = html.fromstring(response.content)
        title_elements = response_tree.xpath('//div[@class="job-title"]/a')
        total_response.append(title_elements)
        
    for sub_response in total_response:
        for val in sub_response:
            flattened_set.append(val)
                  
    for title_tag in flattened_set:
        title = title_tag.text_content().strip()
        link = title_tag.items()[0][1]
        job_titles.append(title)
        job_links.append('https://www.cybercoders.com' + link)
        job_type.append(search_terms)
        
    return job_titles, job_links, job_type

# %%
data_scientist_url = 'https://www.cybercoders.com/search/?searchterms=Data+Scientist&searchlocation=&newsearch=true&originalsearch=true&sorttype=relevance'
data_engineer_url = 'https://www.cybercoders.com/search/?searchterms=Data+Engineer&searchlocation=&newsearch=true&originalsearch=true&sorttype=relevance'
data_analyst_url = 'https://www.cybercoders.com/search/?searchterms=Data+Analyst&searchlocation=&newsearch=true&originalsearch=true&sorttype=relevance'
business_intelligence_url = 'https://www.cybercoders.com/search/?searchterms=Business+Intelligence+&searchlocation=&newsearch=true&originalsearch=true&sorttype=relevance'

search = [data_scientist_url, data_engineer_url, data_analyst_url, business_intelligence_url] # append base urls into a list
search_terms = ['Data Scientist', 'Data Engineer', 'Data Analyst', 'Business Intelligence'] # define search terms

# the number of search results divided by 20 listings per pages which is equal to the number of pages and then round up
# adjust the numerator is needed
num_pages = [int(math.ceil(84 / 20)), int(math.ceil(370 / 20)), int(math.ceil(52 / 20)), int(math.ceil(61 / 20))] # number of pages per search term (number of results divided by 20 listings per page)

# %%
# DATA SCIENTIST DROP DUPLICATES
data_scientist_crawl = shell_crawler(search[0], search_terms[0], num_pages[0])
data_scientist_titles = data_scientist_crawl[0]
data_scientist_links = data_scientist_crawl[1]
data_scientist_type = data_scientist_crawl[2]
ds_check_cols = ['Search', 'Title', 'URL']
ds_check = pd.DataFrame({'Search' : data_scientist_type,
                         'Title' : data_scientist_titles, 
                         'URL' : data_scientist_links}, columns = ds_check_cols)

ds_check = ds_check.drop_duplicates(subset = 'URL', keep = False)
data_scientist_titles = list(ds_check['Title'])
data_scientist_links = list(ds_check['URL'])
data_scientist_type = list(ds_check['Search'])

# %%
# DATA ENGINEER DROP DRUPLICATES
data_engineer_crawl = shell_crawler(search[1], search_terms[1], num_pages[1])
data_engineer_titles = data_engineer_crawl[0]
data_engineer_links = data_engineer_crawl[1]
data_engineer_type = data_engineer_crawl[2]
de_check_cols = ['Search', 'Title', 'URL']
de_check = pd.DataFrame({'Search' : data_engineer_type,
                         'Title' : data_engineer_titles, 
                         'URL' : data_engineer_links}, columns = de_check_cols)

de_check = de_check.drop_duplicates(subset = 'URL', keep = False)
data_engineer_titles = list(de_check['Title'])
data_engineer_links = list(de_check['URL'])
data_engineer_type = list(de_check['Search'])

# %%
# DATA ANALYST DROP DUPLICATES
data_analyst_crawl = shell_crawler(search[2], search_terms[2], num_pages[2])
data_analyst_titles = data_analyst_crawl[0]
data_analyst_links = data_analyst_crawl[1]
data_analyst_type = data_analyst_crawl[2]
da_check_cols = ['Search', 'Title', 'URL']
da_check = pd.DataFrame({'Search' : data_analyst_type,
                         'Title' : data_analyst_titles, 
                         'URL' : data_analyst_links}, columns = da_check_cols)

da_check = da_check.drop_duplicates(subset = 'URL', keep = False)
data_analyst_titles = list(da_check['Title'])
data_analyst_links = list(da_check['URL'])
data_analyst_type = list(da_check['Search'])

# %%
# BUSINESS INTELLIGENCE DROP DUPLICATES
business_intelligence_crawl = shell_crawler(search[3], search_terms[3], num_pages[3])
business_intelligence_titles = business_intelligence_crawl[0]
business_intelligence_links = business_intelligence_crawl[1]
business_intelligence_type = business_intelligence_crawl[2]
bi_check_cols = ['Search', 'Title', 'URL']
bi_check = pd.DataFrame({'Search' : business_intelligence_type,
                         'Title' : business_intelligence_titles, 
                         'URL' : business_intelligence_links}, columns = bi_check_cols)

bi_check = bi_check.drop_duplicates(subset = 'URL', keep = False)
business_intelligence_titles = list(bi_check['Title'])
business_intelligence_links = list(bi_check['URL'])
business_intelligence_type = list(bi_check['Search'])

# %%
job_titles_raw = data_scientist_titles + data_engineer_titles + data_analyst_titles + business_intelligence_titles 
job_links_raw = data_scientist_links + data_engineer_links + data_analyst_links + business_intelligence_links 
job_type_raw = data_scientist_type + data_engineer_type + data_analyst_type + business_intelligence_type

# %%
job_titles_raw
# Out:
# ['Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Lead Data Scientist',
#  'Senior Data Scientist',
#  'Senior Data Scientist',
#  'Senior Data Scientist',
#  'Senior Data Scientist',
#  'Sr. Data Scientist',
#  'Senior Data Scientist',
#  'Senior Data Scientist',
#  'Senior Data Scientist',
#  'Data Scientist (Quantitative Finance)',
#  'Data Scientist (Quantitative Finance)',
#  'Lead Data Scientist',
#  'Lead Data Scientist',
#  'Senior Data Scientist',
#  'Data Scientist (Quantitative Finance)',
#  'Data Scientist (Quantitative Finance)',
#  'Senior Data Scientist',
#  'Chief Data Scientist',
#  'Chief Data Scientist',
#  'Data Scientist (Quantitative Analyst)',
#  'Data Scientist (Quantitative Finance)',
#  'Senior Data Scientist',
#  'Data Scientist - Insurance',
#  'Data Scientist (Smart Manufacturing)',
#  'Mid-Level Data Scientist',
#  'Senior Data Scientist',
#  'Senior Data Scientist',
#  'Lead Data Scientist',
#  'Chief Data Scientist',
#  'Principle Data Scientist',
#  'Chief Data Scientist',
#  'Marketing Data Scientist',
#  'Senior Data Scientist',
#  'Data Scientist/ Engineer',
#  'Principal Data Scientist',
#  'Chief Data Scientist',
#  'Python Engineer/Data Scientist',
#  'Senior Data Scientist',
#  'Lead Data Scientist',
#  'Healthcare Data Scientist',
#  'Senior Data Scientist',
#  'Senior Data Scientist',
#  'Data Scientist -Client Facing',
#  'Lead Data Scientist (Computer Vision)',
#  'Senior Data Scientist - MACHINE LEARNING',
#  'Lead Data Scientist - NLP, Machine Learning',
#  'Data Scientist - FinTech - Fortune 100',
#  'Data Scientist - Python & Machine Learning',
#  'Lead Data Scientist -- NLP, Python or Java',
#  'Data Scientist ** TS/SCI Clearance Required**',
#  'Data Scientist ** TS/SCI Clearance Required**',
#  'Data Scientist & Machine Learning Engineer',
#  'Data Scientist & Machine Learning Engineer',
#  'Data Scientist (R, Python, & SQL)',
#  'Data Scientist (Insurance) - Python, SAS, GLM',
#  'Sr.  Machine Learning Data Scientist - Big Data, Visualization',
#  'Data Scientist | AI Cyber Security Firm (RELOCATION ASSISTANCE!)',
#  'Lead Data Scientist - CNN, Deep Learning - RELOCATION OFFERED!',
#  'Data Scientist - Medical Informatics & Disease Prediction',
#  'Data Scientist - Fully Automated Risk Control Engine!',
#  'Lead Data Scientist - SAS, R, Hive/Pig, Hbase',
#  'Machine Learning Scientist',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Developer',
#  'Senior Python Data Engineer',
#  'Senior Data Engineer',
#  'Senior Big Data Engineer',
#  'Senior Data Engineer',
#  'Lead Data Engineer',
#  'Lead Data Engineer',
#  'Lead Data Engineer',
#  'Senior Data Engineer',
#  'Python Data Engineer',
#  'Sr. Data Engineer',
#  'Senior Data Engineer',
#  'Senior Data Engineer',
#  'Big Data Developer',
#  'Big Data Developer',
#  'Remote-Data Engineer',
#  'Remote- Data Engineer',
#  'Python Data Engineer',
#  'Senior Data Engineer',
#  'Big Data Engineer',
#  'Senior Data Engineer',
#  'Senior Data Engineer',
#  'Senior Data Engineer',
#  'Senior Data Engineer',
#  'Senior Data Engineer',
#  'Senior Data Engineer',
#  'Senior Data Engineer',
#  'Senior Data Engineer',
#  'Senior Data Engineer',
#  'Big Data Engineer',
#  'Senior Data Engineer',
#  'Python Data Engineer',
#  'Senior Data Engineer / Architect',
#  'Data Engineer (Pentaho/ETL/Python)',
#  'Senior Data Engineer (IoT, Embedded)',
#  'Big Data Engineer - Master Data Management',
#  'Senior Big Data Engineer - Hadoop/Kafka',
#  'Big Data Engineer (ETL/AWS/Python)',
#  'Big Data Engineer - Scala, Hadoop, Spark',
#  'Big Data Engineer - Scala, Hadoop, Spark',
#  'Lead Data Engineer - Machine Learning and AI',
#  'Big Data Engineer - Scala, Hadoop, Spark',
#  'Senior Data Engineer (Distributed Systems, Java, Ruby)',
#  'Data Engineer - Paid Relocation to Seattle, WA',
#  'Senior Data Engineer (Distributed Systems, Java, Kafka)',
#  'Senior Data Engineer (Distributed Systems, Java, Kafka)',
#  'Sr Data Infrastructure Engineer',
#  'Sr. Data Warehouse Engineer',
#  'Data Analytics Engineer',
#  'Senior Data Warehouse Developer',
#  'Data Scientist/ Engineer',
#  'Senior Data Systems Engineer',
#  'Big Data Engineer:  Big O Notation Required',
#  'Big Data Engineer:  Big O Notation Required',
#  'Data Warehouse Engineer - Remote',
#  'Lead Big Data Engineer (DoD security clearance required)',
#  'Senior Big Data Engineer -- Java, Hadoop, Spark',
#  'Senior Data Engineer | Need 3+ Years of INDUSTRY Experience!',
#  'Senior Machine Learning Engineer',
#  'Solutions Sales Engineer',
#  'Data Architect/Engineer (Walking Distance to Bart)',
#  'Senior Data Engineer ($200k - 300k) - SMACK Stack, Scala, AWS',
#  'Big Data Software Engineer - TS SCI with CI Polygraph',
#  'Big Data Software Engineer - Hadoop, Kafka, Cloud - TS Clearance',
#  'Software Developer - Big Data',
#  'BI Developer',
#  'Senior Java Engineer - Big Data',
#  'Software Engineer (Clearance Required)',
#  'Senior Engineer and Data Architect',
#  'Senior Engineer and Data Architect',
#  'Product Engineer - Big Data',
#  'Developer',
#  'Data Analytics Software Engineer - Hadoop, Python, Big Data',
#  'Python Developer- Big Data',
#  'Python Engineer/Data Scientist',
#  'Lead Java Engineer - Data Structures, Algorithms',
#  'NetApp/ Data Center Consulting Systems Engineer',
#  'NetApp/ Data Center Consulting Systems Engineer',
#  'NetApp/ Data Center Consulting Systems Engineer',
#  'Data Scientist & Machine Learning Engineer',
#  'Senior GUI Developer (Enterprise, Widgets, Data Center)',
#  'Data Scientist & Machine Learning Engineer',
#  'Cisco Data Center / Network Consulting Engineer',
#  'Senior Software Development Engineer - Data, Hadoop',
#  'Senior Software Engineer -- Java, Big Data',
#  'Senior Software Engineer - Data Distribution',
#  'C++ Senior Software Engineer - Data Distribution',
#  'Software Engineer (Infrastructure/Tools) - Data Monitoring',
#  'Software Engineer (Big Data, Python, AWS)',
#  'Java Big Data Pipeline Software Engineer',
#  'Software Engineer (Big Data, Python, AWS)',
#  'Senior Software Engineer - Linux Big Data',
#  'Senior Software Engineer, Big Data',
#  'Senior Data Scientist',
#  'Python Developer',
#  'BI Developer',
#  'Solution Architect',
#  'Java UI Developer (UI ties into and pulls real-time data)',
#  'Machine Learning Engineer -- Big Data / Analytics Giant!!',
#  'Senior Java Engineer (Spring, Hibernate) - Data Risk Management!',
#  'Sr. Cisco Data Center / Network Consulting Arch / Engineer',
#  'Sr. Software Test Engineer - Data Monitoring Solutions Provider',
#  'Sr. Software Test Engineer - Data Monitoring Platform Provider',
#  'Network/Cloud Engineer - voice & data solutions provider!',
#  'Python Developer',
#  'Sr. Software Developer - C++/Python (Cloud/Big Data Environment)',
#  'Software Engineer (Infrastructure/Tools/DevOp) - Data Monitoring',
#  'iOS Developer',
#  'Linux - Big Data Distribution',
#  'Software Engineer',
#  'Senior ETL Developer',
#  'Database Engineer',
#  'Ruby Developer',
#  'DevOps Engineer',
#  'Front End Engineer',
#  'Full Stack Engineer',
#  'UI Developer',
#  'SQL Developer',
#  'Solutions Engineer ($110k-$130k + Commission)',
#  'Salesforce Engineer',
#  'Senior Java Developer -Partial Remote',
#  'Software Developer',
#  'Database Developer',
#  'Sr. Machine Learning Engineer',
#  'Senior Java Developer',
#  'Senior Full Stack Engineer',
#  'Senior Java Developer',
#  'Lead Full Stack Engineer',
#  'Senior Database Developer',
#  'Machine Learning Engineer',
#  'Machine Learning Engineer',
#  'Machine Learning Engineer',
#  'SQL Integration Engineer',
#  'Senior Machine Learning Engineer',
#  'Senior ETL Developer',
#  'Back End Engineer',
#  'Full Stack Engineer',
#  'Customer Success Engineer ($100k-$120k)',
#  'Software Engineer',
#  'Software Engineer',
#  'Lead Data Scientist -- NLP, Python or Java',
#  'Sr. Java Developer',
#  'Sr. Java Engineer',
#  'Senior .NET C# Developer',
#  'Senior DevOps Engineer',
#  'Machine Learning Engineer',
#  'Machine Learning Engineer',
#  'Mobile Developer - iOS',
#  'Operations Support Engineer',
#  'Senior Java Engineer',
#  'Senior Android Engineer - Will Relocate',
#  'Full-Stack Developer',
#  'Senior Machine Learning Engineer',
#  'Senior Machine Learning Engineer',
#  'Senior QA Engineer (Python/Java)',
#  'Software Engineer',
#  'Software Engineer',
#  'Lead Application Developer',
#  'Lead Software Development Engineer',
#  'Senior Ruby Developer',
#  'Lead Software Development Engineer',
#  'Lead Software Development Engineer',
#  'QA Engineer - Blockchain',
#  'Automated Test Engineer',
#  'Lead Software Development Engineer',
#  'Senior Web Applications Developer',
#  'Senior Network Security Engineer',
#  'Senior Web Applications Developer',
#  'Full-Stack Developer',
#  'Test Automation Developer',
#  'Senior Extrusion Engineer',
#  'Senior Java Engineer',
#  'Senior Machine Learning Engineer',
#  'Machine Learning Engineer',
#  'FPGA Design Engineer',
#  'Front End Developer',
#  'SQL Developer',
#  'Database Developer',
#  'Senior Software Engineer (Big Date/Python)',
#  '.NET Developer',
#  'PYTHON Engineer',
#  'Network Engineer',
#  'Network Engineer',
#  'Senior Software Developer',
#  'GoLang Developer',
#  'Full Stack Engineer',
#  'Full Stack Developer',
#  'Performance Engineer',
#  'Full Stack Developer',
#  'Performance Engineer',
#  'Sr. Salesforce Developer',
#  'Salesforce Developer (Lightning/Java)',
#  'Senior Salesforce Developer',
#  'Lead Frontend Developer',
#  'IT Security Engineer',
#  'Senior Web Developer',
#  'Full Stack Web Developer',
#  'Principal Ruby on Rails Engineer',
#  'Full Stack Developer - Angular, Java',
#  'Senior Cloud Engineer  -- AWS',
#  'Sr. Software Engineer',
#  'Sr. Software Engineer',
#  'Senior Java Developer',
#  'Senior Algorithm Engineer',
#  'Lead Android Engineer',
#  'Senior Android Engineer',
#  'Senior Java Engineer',
#  'Mixed Signal Design Engineer',
#  'Senior Algorithm Engineer',
#  'Supplier Quality Engineer',
#  'C++ Engineer (Multi-threaded)',
#  'Full-Stack JavaScript Developer',
#  'Senior Algorithm Engineer',
#  'Lead Ad Platform Engineer',
#  'Lead Software Platform Engineer',
#  'Golang Software Developer | WE WILL RELOCATE YOU!',
#  'Senior Software Developer',
#  'Senior Software Engineer',
#  'PID Controls Engineer',
#  'Senior Database Engineer',
#  'Network Sales Engineer',
#  'Senior Server Developer',
#  'Sr. Network Pre Sales Engineer',
#  'Sr. Network Pre Sales Engineer',
#  'Software QA & Python Developer',
#  'Full-Stack Developer (C# and .NET)',
#  'DBA/DB Engineer (SQL Server)',
#  'Lead Software Engineer',
#  'Lead Software Engineer',
#  'Senior Software Developer',
#  'Java Software Developer',
#  'SWAT Software Developer',
#  'Ruby on Rails Software Engineer',
#  'Software Engineer - Kafka Expert',
#  'Senior Software Engineer',
#  'Software Development Engineer - ALL LEVELS, WILL RELOCATE',
#  'Senior Software Development Engineer - WILL RELOCATE',
#  'Senior Platform Engineer - Rails, Angular.js',
#  'Sr. Power BI Developer - REMOTE',
#  'Sr. Power BI Developer - REMOTE',
#  'Mobile Developer - High Growth Opportunity!',
#  'Data Scientist | AI Cyber Security Firm (RELOCATION ASSISTANCE!)',
#  'Lead/Senior Mobile Engineer (Android)',
#  'Lead/Senior Mobile Engineer (Android)',
#  'Senior Database Engineer - Java',
#  'Senior Software Engineer',
#  'Lead/Manager Software Engineer',
#  'Senior Software Engineer - Cryptocurrency',
#  'SIEM Engineer  - ArcSight, Splunk',
#  'Senior Platform Engineer - Ruby/Scala',
#  'Senior Back-End / GoLang Engineer',
#  'Cybersecurity/Information Assurance Engineer (TS/SCI Required)',
#  'Sr. Front End Developer (Casual Office/Flexible Hours)',
#  'Software Engineer, Big Data - ACTIVE TS/SCI w FS Poly - 12124',
#  'Software Engineer, Big Data - ACTIVE TS/SCI w FS Poly - 12124',
#  'Senior Java Engineer',
#  'Ruby on Rails Developer',
#  'Magento Developer - eCommerce!',
#  'Senior Java Engineer',
#  'Principal Java Developer',
#  'Principal Java Developer',
#  'SQL Developer (relocation offered)',
#  'Software Engineer -- Machine Learning, NLP',
#  'Software Engineer - Java / Scala',
#  'Java DevOps Engineer',
#  'SCALA Cloud Engineer',
#  '.NET Developer -  SQL',
#  'Web UI Developer',
#  'Sr Full Stack JavaScript Engineer',
#  'Senior Devops Engineer',
#  'Senior Devops Engineer',
#  'Deep Learning Engineer',
#  'Sr. UI Engineer',
#  'Machine Learning Engineer',
#  'Lead DevOps Engineer',
#  'Performance Test  Engineer',
#  'Senior DevOps Engineer (Python)',
#  'Software Development Engineer in Test',
#  'Full-Stack  Engineer',
#  'Blockchain Smart Contracts Engineer',
#  'Professional Services Engineer',
#  'Lead UI Engineer',
#  'Software Development Engineer in Test',
#  'Senior Fullstack Web Developer',
#  'Mechanical Engineer - Solidworks, UAV, Drones!!!',
#  'Senior Software Development Engineer - $200k +',
#  'Director of Computer Vision Engineer - Python & TensorFlow!',
#  'Full-Stack Engineer (Backend) - RoR and Storage Expert',
#  'Software Engineer - C++ - Multi-thread - Algorithm Development',
#  'Remote/Onsite Web Developer (Javascript and Angular/React)',
#  'Senior Web Developer (Javascript and Angular/React)',
#  'Principle Engineer -  Embedded Product Development',
#  'Sr. Software  Engineer  - C++/Multi-Threaded',
#  'Sr. Software  Engineer  - C++/Multi-Threaded',
#  'Senior C/C++ Developer - Medical Device Startup',
#  'Quality Specialist Engineer - ISO 13485 ISO 9001',
#  'Cisco Security Lead Regional Solutions Engineer / Architect',
#  'Senior Ruby on Rails Developer for Top Market Research company!',
#  'Senior Software Engineer (C#, .Net) with some embedded',
#  'WPF Engineer - RELOCATE today!',
#  'Business Intelligence Developer - ETL',
#  'Senior Software  Engineer',
#  'Principal Software Engineer (.NET)',
#  'Senior Software Engineer (.NET)',
#  'Lead Software Developer',
#  'Blockchain Developer - Preferably Ethereum',
#  'Senior Front End Developer (Relocate to Tampa)',
#  'Senior Software Engineer',
#  'Software Development Engineer - C++, Linux, RedHat, Embedded',
#  'STAFF HARDWARE ENGINEER - ENTERPRISE SSD',
#  "Software Test Engineer (Automation) REQ'D C++/Python/Linux",
#  'Sr. Software Automation Engineer (Cloud) -  C++/Python/Linux',
#  'Senior Air Quality Engineer - Bay Area/Berkeley',
#  'Lead Quality Engineer Specialist - $100k - ISO 9001 13485',
#  'C++ Software Engineer - Search Team',
#  'Sr. Software  Engineer (SaaS/AI) - C++ OOP/OOD',
#  'Senior Software Engineer - Java/Spring, LIMS, DNA Sequencing',
#  'Software Engineer - Active TS/SCI CI Poly - 11485G6',
#  'Staff Software Engineer -  C++, STL, Power Analysis Tools',
#  'Senior iOS Engineer - SWIFT, Objective C, iOS Frameworks/SDK!',
#  'Electrical Engineer - URGENT ROLE -  Electrical System Design',
#  'Electrical Engineer - 3D Modeling - Saint Paul',
#  'Software Engineer - C#, Windows',
#  'Full Stack Engineer - Python/React or Angular/AWS',
#  'Sr. Software Developer in Test (Automation) - C++/Python/Linux',
#  'Cloud Engineer - TS/SCI w/FSP or CI',
#  'Remote Senior Application Engineer - SAP Hybris/Back-End',
#  "Software Test Engineer (Automation - LA) REQ'D C++/Python/Linux",
#  'Sr Software Engineer - Active TS/SCI CI Poly - 114854',
#  'BI Engineer- fulltime - own a flexible client base!',
#  'BI Architect/Engineer',
#  'Sr. Software Developer - Java/C++/Python',
#  'Full Stack Software Engineer - JavaScript, SaaS',
#  'Sr Software Engineer - Python, NoSQL, Spark',
#  'Software Engineer - C#, CRM',
#  'Senior Java Developer- Innovative Company!',
#  'Senior Java Developer- Partial Remote',
#  'Senior Java Developer- Innovative Company!',
#  'Sr. Back End Developer (TS/SCI + FSP Clearance)',
#  'Java Developer - Java/J2EE, Linux/UNIX, Web Services',
#  'Senior / Lead ReactJS Developer - GraphQL, RESTful, Docker',
#  'Lead Cloud Architect/Engineer - Machine Learning and AI',
#  'Rapid Application Developer(RAD)- Team Lead',
#  'Lead Developer- MS Dynamics 365',
#  'Controls Systems Engineer, Matlab/Simulink',
#  'Sr. Test Engineer - Hardware, LabView, TestStand - (80K - 100K)',
#  'Programmer',
#  'Machine Learning Engineer- Deep Learning - RELOCATION OFFERED!',
#  'Electrical Design Engineer-  Complex  Electrical Infrastructure',
#  'Controls Engineer, PLC, HMI, AutoCAD, Motion Control',
#  'Verification Engineer- ASIC/SoC, verification flows -(160K-190K)',
#  'ASIC/SoC Verification Engineer- verification flows -(160K-190K)',
#  'Senior Database Engineer- (Java / PostgreSQL)',
#  'Senior Software Engineer- (Java / PostgreSQL)',
#  'Machine Learning Scientist',
#  'NodeJS / NPM / Socket.IO - Senior Back-end Javascript / Node.JS',
#  'SDET',
#  'Network Solutions Architect (SDN, SD-WAN, DC)',
#  'Network Solutions Architect (SDN, SD-WAN, DC)',
#  'Lead Cloud Infrastructure Engineer- SaaS/PaaS/HDFS',
#  'Database Architect',
#  'Data Analyst',
#  'Data Analyst',
#  'Senior Data Analyst',
#  'Marketing Data Analyst',
#  'Senior Data Analyst',
#  'Lead Data Analyst',
#  'Entry-Level Marketing Data Analyst',
#  'Junior Data Analyst - Math, Data, Excel',
#  'Data Reporting Analyst',
#  'Data Reporting Analyst',
#  'Data Management Analyst',
#  'Lead Data Science Analyst',
#  'Senior Data Science Analyst',
#  'Data Warehouse Analyst',
#  'Data Analyst - Full Scope / Lifestyle Clearance',
#  'Data Analyst - R, Excel, or SAS, Data Visualization/Dashboarding',
#  'Data Analyst - R, Data Visualization/Dashboarding (Tableau)',
#  'Data Analyst (R // Tableau) - World-Renowned School System!',
#  'Mid-Level Data Scientist',
#  'Data Scientist',
#  'Operations Analyst Manager',
#  'Data Scientist (Quantitative Analyst)',
#  'Business Analyst',
#  'Business Analyst',
#  'Business Analyst',
#  'Healthcare Business Analyst',
#  'Marketing Analyst',
#  'Financial  Analyst',
#  'Reporting Analyst',
#  'Sr. Business Analyst (Salesforce.com)',
#  'Financial Analyst',
#  'Financial Analyst',
#  'Senior Information Security Analyst',
#  'Senior Information Security Analyst',
#  'Information Security Analyst',
#  'Business Analyst, BI',
#  'Operations Financial Analyst',
#  'Application Support Analyst',
#  'Project Control Analyst',
#  'Senior Project Control Analyst',
#  'Lead Salesforce Analyst',
#  'Lead Salesforce Analyst',
#  'Business Analyst - Internal Business Process Improvements',
#  'Junior Business Analyst - Internal Policies and Procedures',
#  'Sr. QA Test Analyst',
#  'Sr. QA Analyst',
#  'Financial Analyst - Public Biopharma',
#  'Marketing/Scheduling Analyst- Home Building',
#  'Business Process Analyst',
#  'Application Analyst - Payroll, Benefits, User Security',
#  'BI Analyst | Work/Life Balance (40 Hour Work Week!)',
#  'Programmer Analyst - C#, ASP.NET',
#  'BI Developer',
#  'BI Director',
#  'BI Developer',
#  'Business Analyst, BI',
#  'BI Report Developer',
#  'BI Report Developer',
#  'Sr. Business Intelligence Developer',
#  'Director of Business Intelligence',
#  'Director of Business Intelligence',
#  'Oracle BI Solution Architect',
#  'Oracle BI Solution Architect',
#  'Product Manager - Business Intelligence',
#  'Business Intelligence Developer - ETL',
#  'BI Engineer- fulltime - own a flexible client base!',
#  'Senior Claims Representative - BI experience!',
#  'BI Developer  - Azure SQL, PowerBI',
#  'Sr. Power BI Developer - REMOTE',
#  'Sr. Power BI Developer - REMOTE',
#  'BI Architect/Engineer',
#  'SQL Development Specialist - Data Extraction, Power BI',
#  'BI Analyst | Work/Life Balance (40 Hour Work Week!)',
#  'Data Warehouse Architect',
#  'Director of Analytics (SQL, Tableau)',
#  'Database Developer',
#  'Account Executive - SaaS, Analytics/Data',
#  'Sr ETL / Tableau Developer',
#  'Director of Delivery - Data Analytics, Big Data, ETL, BI, DW',
#  'Sr. Software Systems Developer',
#  'Technical Customer Success Manager',
#  'Oracle Applications Developer',
#  'Director of Analytics',
#  'Director of Delivery - Retail/E-Commerce',
#  'Solutions Engineer ($110k-$130k + Commission)',
#  'Customer Success Engineer ($100k-$120k)',
#  'Solutions Architect - Excel, SQL, Tableau',
#  'JD Edwards EnterpriseOne Developer',
#  'Software Developer (SSIS/SSRS)',
#  'Java Software Developer',
#  'Senior Product Marketing Manager',
#  'Lead Solutions Architect ($100k-$150k)',
#  'Information Architect',
#  'Developer',
#  'Programmer',
#  'JD Edwards EnterpriseOne Developer',
#  'SWAT Software Developer',
#  'Lead Solutions Architect',
#  'JD Edwards EnterpriseOne Developer',
#  'Senior Product Manager',
#  'SharePoint Developer (Applications Management)',
#  'Microsoft Developer',
#  'JD Edwards Enterprise One 9.1 Specialist - Construction Industry',
#  'Developer/Project Manager with SharePoint experience',
#  'Accounting Manager',
#  'Financial Analyst',
#  'Database Architect',
#  'Lead Java Engineer - Data Structures, Algorithms',
#  'Lead Java Engineer - SOA, Micro-Services',
#  'Sr Back-End Engineer - Java, SaaS',
#  'Lead Platform Engineer/Architect - SOA, Micro-Services, Java',
#  'Senior Full Stack Developer - ASP.NET MVC, C#',
#  'Machine Learning Evangelist - Ai',
#  'Director of Market Development - Ai',
#  'Ai Software Executive - Evangelist',
#  'Senior Product Marketing Manager',
#  'Sales Representative - Software / Mobile Solutions']

# %%
job_links_raw
# Out:
# ['https://www.cybercoders.com/data-scientist-job-197502',
#  'https://www.cybercoders.com/data-scientist-job-399265',
#  'https://www.cybercoders.com/data-scientist-job-413368',
#  'https://www.cybercoders.com/data-scientist-job-413617',
#  'https://www.cybercoders.com/data-scientist-job-414239',
#  'https://www.cybercoders.com/data-scientist-job-414707',
#  'https://www.cybercoders.com/data-scientist-job-415915',
#  'https://www.cybercoders.com/data-scientist-job-417109',
#  'https://www.cybercoders.com/data-scientist-job-420208',
#  'https://www.cybercoders.com/data-scientist-job-420497',
#  'https://www.cybercoders.com/data-scientist-job-420982',
#  'https://www.cybercoders.com/data-scientist-job-421067',
#  'https://www.cybercoders.com/data-scientist-job-422846',
#  'https://www.cybercoders.com/data-scientist-job-424349',
#  'https://www.cybercoders.com/data-scientist-job-425176',
#  'https://www.cybercoders.com/data-scientist-job-425588',
#  'https://www.cybercoders.com/data-scientist-job-426052',
#  'https://www.cybercoders.com/data-scientist-job-427410',
#  'https://www.cybercoders.com/data-scientist-job-427585',
#  'https://www.cybercoders.com/data-scientist-job-428379',
#  'https://www.cybercoders.com/lead-data-scientist-job-224027',
#  'https://www.cybercoders.com/senior-data-scientist-job-369387',
#  'https://www.cybercoders.com/senior-data-scientist-job-372355',
#  'https://www.cybercoders.com/senior-data-scientist-job-372358',
#  'https://www.cybercoders.com/senior-data-scientist-job-390523',
#  'https://www.cybercoders.com/sr-data-scientist-job-390582',
#  'https://www.cybercoders.com/senior-data-scientist-job-393702',
#  'https://www.cybercoders.com/bi-architect-engineer-job-391714',
#  'https://www.cybercoders.com/sr-software-developer-java-c-plus-plus-python-job-242297',
#  'https://www.cybercoders.com/full-stack-software-engineer-javascript-saas-job-397667',
#  'https://www.cybercoders.com/sr-software-engineer-python-nosql-spark-job-418991',
#  'https://www.cybercoders.com/software-engineer-c-sharp-crm-job-428407',
#  'https://www.cybercoders.com/senior-java-developer-innovative-company-job-412631',
#  'https://www.cybercoders.com/senior-java-developer-partial-remote-job-416993',
#  'https://www.cybercoders.com/senior-java-developer-innovative-company-job-428011',
#  'https://www.cybercoders.com/sr-back-end-developer-ts-sci-fsp-clearance-job-346126',
#  'https://www.cybercoders.com/java-developer-java-j2ee-linux-unix-web-services-job-397942',
#  'https://www.cybercoders.com/senior-lead-reactjs-developer-graphql-restful-docker-job-410618',
#  'https://www.cybercoders.com/lead-cloud-architect-engineer-machine-learning-and-ai-job-423270',
#  'https://www.cybercoders.com/rapid-application-developer-rad-team-lead-job-420941',
#  'https://www.cybercoders.com/lead-developer-ms-dynamics-365-job-407703',
#  'https://www.cybercoders.com/controls-systems-engineer-matlab-simulink-job-414900',
#  'https://www.cybercoders.com/sr-test-engineer-hardware-labview-teststand-80k-100k-job-421642',
#  'https://www.cybercoders.com/programmer-job-426379',
#  'https://www.cybercoders.com/machine-learning-engineer-deep-learning-relocation-offered-job-370079',
#  'https://www.cybercoders.com/electrical-design-engineer-complex-electrical-infrastructure-job-419717',
#  'https://www.cybercoders.com/controls-engineer-plc-hmi-autocad-motion-control-job-427076',
#  'https://www.cybercoders.com/verification-engineer-asic-soc-verification-flows-160k-190k-job-379771',
#  'https://www.cybercoders.com/asic-soc-verification-engineer-verification-flows-160k-190k-job-379963',
#  'https://www.cybercoders.com/senior-database-engineer-java-postgresql-job-411605',
#  'https://www.cybercoders.com/senior-software-engineer-java-postgresql-job-412439',
#  'https://www.cybercoders.com/machine-learning-scientist-job-403235',
#  'https://www.cybercoders.com/nodejs-npm-socket-io-senior-back-end-javascript-node-js-job-411372',
#  'https://www.cybercoders.com/sdet-job-424167',
#  'https://www.cybercoders.com/network-solutions-architect-sdn-sd-wan-dc-job-415527',
#  'https://www.cybercoders.com/network-solutions-architect-sdn-sd-wan-dc-job-416085',
#  'https://www.cybercoders.com/lead-cloud-infrastructure-engineer-saas-paas-hdfs-job-420432',
#  'https://www.cybercoders.com/database-architect-job-426452',
#  'https://www.cybercoders.com/data-analyst-job-423586',
#  'https://www.cybercoders.com/data-analyst-job-426818',
#  'https://www.cybercoders.com/senior-data-analyst-job-404767',
#  'https://www.cybercoders.com/marketing-data-analyst-job-409968',
#  'https://www.cybercoders.com/senior-data-analyst-job-417596',
#  'https://www.cybercoders.com/lead-data-analyst-job-424002',
#  'https://www.cybercoders.com/entry-level-marketing-data-analyst-job-421971',
#  'https://www.cybercoders.com/junior-data-analyst-math-data-excel-job-425290',
#  'https://www.cybercoders.com/data-reporting-analyst-job-248921',
#  'https://www.cybercoders.com/sharepoint-developer-applications-management-job-389114',
#  'https://www.cybercoders.com/microsoft-developer-job-389330',
#  'https://www.cybercoders.com/jd-edwards-enterprise-one-9-1-specialist-construction-industry-job-417761',
#  'https://www.cybercoders.com/developer-project-manager-with-sharepoint-experience-job-421891',
#  'https://www.cybercoders.com/accounting-manager-job-419009',
#  'https://www.cybercoders.com/financial-analyst-job-419522',
#  'https://www.cybercoders.com/database-architect-job-284014',
#  'https://www.cybercoders.com/lead-java-engineer-data-structures-algorithms-job-401878',
#  'https://www.cybercoders.com/lead-java-engineer-soa-micro-services-job-401882',
#  'https://www.cybercoders.com/sr-back-end-engineer-java-saas-job-409211',
#  'https://www.cybercoders.com/lead-platform-engineer-architect-soa-micro-services-java-job-428554',
#  'https://www.cybercoders.com/senior-full-stack-developer-asp-dot-net-mvc-c-sharp-job-386033',
#  'https://www.cybercoders.com/machine-learning-evangelist-ai-job-422585',
#  'https://www.cybercoders.com/director-of-market-development-ai-job-422592',
#  'https://www.cybercoders.com/ai-software-executive-evangelist-job-425839',
#  'https://www.cybercoders.com/senior-product-marketing-manager-job-425447',
#  'https://www.cybercoders.com/sales-representative-software-mobile-solutions-job-385588']

# %%
job_type_raw
# Out:
# ['Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Business Intelligence',
#  'Business Intelligence',
#  'Business Intelligence',
#  'Business Intelligence',
#  'Business Intelligence',
#  'Business Intelligence',
#  'Business Intelligence',
#  'Business Intelligence',
#  'Business Intelligence',
#  'Business Intelligence',
#  'Business Intelligence',
#  'Business Intelligence',
#  'Business Intelligence',
#  'Business Intelligence',
#  'Business Intelligence',
#  'Business Intelligence',
#  'Business Intelligence',
#  'Business Intelligence',
#  'Business Intelligence',
#  'Business Intelligence',
#  'Business Intelligence',
#  'Business Intelligence',
#  'Business Intelligence',
#  'Business Intelligence',
#  'Business Intelligence',
#  'Business Intelligence',
#  'Business Intelligence',
#  'Business Intelligence',
#  'Business Intelligence',
#  'Business Intelligence',
#  'Business Intelligence',
#  'Business Intelligence',
#  'Business Intelligence',
#  'Business Intelligence',
#  'Business Intelligence',
#  'Business Intelligence',
#  'Business Intelligence',
#  'Business Intelligence',
#  'Business Intelligence',
#  'Business Intelligence',
#  'Business Intelligence',
#  'Business Intelligence',
#  'Business Intelligence',
#  'Business Intelligence',
#  'Business Intelligence',
#  'Business Intelligence',
#  'Business Intelligence',
#  'Business Intelligence',
#  'Business Intelligence',
#  'Business Intelligence',
#  'Business Intelligence',
#  'Business Intelligence',
#  'Business Intelligence',
#  'Business Intelligence',
#  'Business Intelligence',
#  'Business Intelligence',
#  'Business Intelligence',
#  'Business Intelligence',
#  'Business Intelligence',
#  'Business Intelligence',
#  'Business Intelligence',
#  'Business Intelligence',
#  'Business Intelligence',
#  'Business Intelligence',
#  'Business Intelligence']

# %%
# drop duplicates
dcheck_cols = ['Search', 'Title', 'URL']
dcheck_df = pd.DataFrame({'Search' : job_type_raw,
                          'Title': job_titles_raw,
                          'URL' : job_links_raw}, columns = dcheck_cols)

# %%
# drop duplicates conditioned on the URLS
dcheck_df = dcheck_df.drop_duplicates(subset = 'URL', keep = False)
job_titles = list(dcheck_df['Title'])
job_links = list(dcheck_df['URL'])
job_type = list(dcheck_df['Search'])

# %%
def location(newtree, location_list):
    """
    (Purpose)
    Helper function for extracting the location corresponding to each job listing.
    This is called from the "job_crawler" function. 
    
    (Arguments)
    newtree : html tree for each job listing
    
    (Returns)
    location_list : list of locations for each of the listings
    """
    loelements = newtree.xpath('//div[@class="location"]')[0]
    locationcontent = loelements.text_content().strip()
    location_list.append(locationcontent)
    location_list =  ''.join(str(i) for i in location_list)

# %%
def wage(newtree, wage_list):
    """
   (Purpose)
    Helper function for extracting the wage corresponding to each job listing.
    This is called from the "job_crawler" function. 
    
    (Arguments)
    newtree : html tree for each job listing
    
    (Returns)
    wage_list : list of wages for each of the listings
    """
    waelements = newtree.xpath('//div[@class="wage"]')[0]
    wagecontent = waelements.text_content().strip()
    wagecontent = re.findall('\d+', wagecontent )
    wage_list.append(wagecontent)

# %%
def description(newtree, description_list):
    """
    (Purpose)
    Helper function for extracting the description corresponding to each job listing.
    This is called from the "job_crawler" function. 
    
    (Arguments)
    newtree : html tree for each job listing
    
    (Returns)
    description_list : list of descriptions for each of the listings
    """
    jdelements = newtree.xpath('//div[@class="job-details"]')[0]
    detailcontent = jdelements.text_content().strip()
    description_list.append(detailcontent)
    description_list = ''.join(str(i) for i in description_list)

# %%
def skills(newtree, skills_list):
    """
    (Purpose)
    Helper function for extracting the skills corresponding to each job listing.
    This is called from the "job_crawler" function. 
    
    (Arguments)
    newtree : html tree for each job listing
    
    (Returns)
    skills_list : list of skills required for each of the listings
    """
    preferelements = newtree.xpath('//div[@class="skills-section"]')[0]
    prefercontent = preferelements.text_content().strip(' \t\n\r')
    skills_list.append(prefercontent)
    skills_list = ''.join(str(i) for i in skills_list)

# %%
# Now have job titles on each page and their links
# Iterate through each page, crawl through each listing, and extract (location, wages, descriptions, skills)

def job_crawler(job_links):
    """
    (Purpose)
    Using the links returned from the "shell_crawler" function, this function extracts the 
    details relating to each job listing. 
    
    (Arguments)
    job_links : list of the urls corresponsing to each listing of the search results
    
    (Returns)
    location_list : list of locations for each of the listings
    wage_list : list of wages for each of the listings
    description_list : list of descriptions for each of the listings
    skills_list : list of skills required for each of the listings
    """
    
    location_list = []
    wage_list = []
    description_list = []
    skills_list = []
    
    for url in job_links:
        response = requests.get(url)
        response_tree = html.fromstring(response.content)
        
        location(response_tree, location_list) # call location helper function
        wage(response_tree, wage_list) # call wage helper function
        description(response_tree, description_list) # call description helper function
        skills(response_tree, skills_list) # call skills helper funciton
        #time.sleep(0.15)
    
    return location_list, wage_list, description_list, skills_list

# %%
def geo_cords(jobs_df, field):
    
    latitude = []
    longitude = []
    
    nrows, ncols = jobs_df.shape
    
    for i in range(nrows):
        address = jobs_df[field][i]
        api_key = "AIzaSyA_bzUIipMaoeuqNQkm_62YaVK-YZgOKFc"
        api_response = requests.get('https://maps.googleapis.com/maps/api/geocode/json?address={0}&key={1}'.format(address, api_key))
        api_response_dict = api_response.json()
        i +=1
        if api_response_dict['status'] == 'OK':
            lat = api_response_dict['results'][0]['geometry']['location']['lat']
            lon = api_response_dict['results'][0]['geometry']['location']['lng']
            
            latitude.append(lat)
            longitude.append(lon)
    
    return latitude, longitude

# %%
# using the title and links crawl through the listings and extract the key information
listing_crawl = job_crawler(job_links)
location_list = listing_crawl[0]
wage_list = listing_crawl[1]
description_list = listing_crawl[2]
skills_list = listing_crawl[3]

# %%
# create final dataframe
df_columns = ['Search', 'Title','Location','Salary','Description','Skills','URL']
raw_jobs_data_df = pd.DataFrame({'Search' : job_type,
                                 'Title': job_titles,
                                 'Location' : location_list, 
                                 'Salary' : wage_list, 
                                 'Description' : description_list, 
                                 'Skills' : skills_list, 
                                 'URL' : job_links}, columns = df_columns)

geo_list = geo_cords(raw_jobs_data_df, 'Location')
raw_jobs_data_df['Latitude'] = geo_list[0]
raw_jobs_data_df['Longitude'] = geo_list[1]
raw_jobs_data_df = raw_jobs_data_df[['Search','Title','Description', 'Skills', 'Location', 'Latitude', 'Longitude', 'Salary', 'URL']]

# %%
raw_jobs_data_df.to_csv('raw_jobs_data.csv', index = False)

# %%
w1 = '/Users/tmm/Documents/GitHub/STA160-Project/Working/cyber_coders/Data'
os.chdir(w1)
raw_jobs_out = open('raw_jobs_data.pickle', 'wb')
pickle.dump(raw_jobs_data_df, raw_jobs_out)
raw_jobs_out.close()
