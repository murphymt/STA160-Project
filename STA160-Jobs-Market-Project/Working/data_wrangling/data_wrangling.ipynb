# %%
import os
import pickle
import pandas as pd

wd2 = "/Users/tmm/Documents/GitHub/STA160-Project/STA160-Jobs-Market-Project/Data"
os.chdir(wd2)

jobs_scrub_in = open('raw_jobs_data.pickle', 'rb')
jobs_scrub = pickle.load(jobs_scrub_in)


jobs_scrub.columns = ['Search','Title','Description', 'Skills', 'Location', 'Latitude', 'Longitude', 'Salary', 'URL']

wd3 = "/Users/tmm/Documents/GitHub/STA160-Project/STA160-Jobs-Market-Project"
os.chdir(wd3)

# %%
def skills_clean(jobs_scrub, field):
    """
    (Purpose)
    Cleans up the skills for each listing. The raw data has 'Preferred Skills', '\r', and \n'
    that need to be removed in order to have a cleaner format. 
    
    (Arguments)
    field : Skills
    
    (Returns)
    skills : list of scrubbed skills
    
    """
    nrows, ncols = jobs_scrub.shape
    
    removals1 = ['Preferred Skills', '\r', '\n']
    for i in range(nrows):
        for j in removals1:
            holder1 = jobs_scrub[field][i].replace(j,'')
            jobs_scrub.loc[i,field] = holder1
        #jobs_scrub.loc[i,field] = jobs_scrub.loc[i,field].split('  ')
    
    skills_split = lambda jobs_scrub : jobs_scrub[field].split('  ')
    jobs_scrub[field] = jobs_scrub.apply(skills_split, axis = 1)
    
    none_removal = lambda jobs_scrub : list(filter(None, jobs_scrub[field]))
    jobs_scrub[field] = jobs_scrub.apply(none_removal, axis = 1)
    
    jobs_scrub[field] = jobs_scrub[field].apply(lambda jobs_scrub: ', '.join(map(str, jobs_scrub)))
    
    return jobs_scrub[field]

# %%
def description_scrub(jobs_scrub, field):
    """
    (Purpose)
    Cleans up the description for each listing. The raw data has '*', '\r', \n', and 
    'Applicants must be authorized to work in the U.S.' that need to be removed in order 
    to have a cleaner format. 
    
    (Arguments)
    field : Description
        
    (Returns)
    description : list of scrubbed descriptions
    
    """
    nrows, ncols = jobs_scrub.shape
    
    removals = ['*','\r','\n','Applicants must be authorized to work in the U.S.']
    for i in range(nrows):
        for j in removals:
            holder = jobs_scrub[field][i].replace(j,'')
            jobs_scrub.loc[i,field] = holder
    return jobs_scrub[field]

# %%
def location_clean(jobs_scrub, field):
    """
    (Purpose)
    Seperates the locations for each listing into city and states, which is a cleaner format for
    conducting analysis later on. 
    
    (Arguments)
    field : Location
    
    (Return)
    city : list of cities for job listings
    state : list of state for job listings
    
    """
    nrows, ncols = jobs_scrub.shape
    cities = []
    states = []
    for i in range(nrows):
        location_split = jobs_scrub[field][i].split(', ')
        cities.append(location_split[0])
        states.append(location_split[1])
    return cities, states

# %%
def salary_clean(jobs_scrub, field):
    """
    (Purpose)
    Cleans up the salary portion for each listing if there is data present. Seperates the salary
    estimates into a minimum and maximum salary estimate. Also, the format is converted into thousands
    and numeric. 
    
    (Arguments)
    field : Salary
    
    (Return)
    min_salary : list of minimum salary estimates
    max_salary : list of maximum salary estimates
    
    """
    nrows, ncols = jobs_scrub.shape
    min_salary = []
    max_salary = []
    mean_salary = []

        
    for i in range(nrows):
        for j in range(len(jobs_scrub[field][i])):
            if len(jobs_scrub[field][i][j]) >= 2:
                jobs_scrub[field][i][j] = jobs_scrub[field][i][j] + '000'
                jobs_scrub[field][i][j] = int(jobs_scrub[field][i][j])
    
    for i in range(nrows):
        if len(jobs_scrub[field][i]) == 0:
            jobs_scrub[field][i].append(0)
            jobs_scrub[field][i].append(0)
    
    for i in range(nrows):
        min_salary.append(jobs_scrub[field][i][0])
        max_salary.append(jobs_scrub[field][i][1])
        mean_salary.append((jobs_scrub[field][i][0] + jobs_scrub[field][i][1]) / 2)
        
    for i in range(nrows):
        if min_salary[i] == 0:
            min_salary[i] = 'Unknown'
        if max_salary[i] == 0:
            max_salary[i] = 'Unknown'
        if mean_salary[i] ==0:
            mean_salary[i] = 'Unknown'
            
            
    return min_salary, max_salary, mean_salary

# %%
description_list = description_scrub(jobs_scrub, 'Description')
skills_list = skills_clean(jobs_scrub, 'Skills')
locations_list = location_clean(jobs_scrub, 'Location')
wage_list = salary_clean(jobs_scrub, 'Salary')

jobs_scrub['Description'] = description_list
jobs_scrub['Skills'] = skills_list
jobs_scrub['Cities'] = locations_list[0]
jobs_scrub['States'] = locations_list[1]
jobs_scrub['Min_Salary'] = wage_list[0]
jobs_scrub['Max_Salary'] = wage_list[1]
jobs_scrub['Mean_Salary'] = wage_list[2]
jobs_scrub = jobs_scrub[jobs_scrub['Description'] != '']

jobs_scrub = jobs_scrub[['Search', 
                         'Title',
                         'Description',
                         'Skills',
                         'Location',
                         'Cities', 
                         'States', 
                         'Latitude', 
                         'Longitude', 
                         'Min_Salary', 
                         'Max_Salary', 
                         'Mean_Salary', 
                         'URL']]

# %%
jobs_scrub
# Out:
#                     Search                                              Title  \
# 0           Data Scientist                                     Data Scientist
# 1           Data Scientist                                     Data Scientist
# 2           Data Scientist                                     Data Scientist
# 3           Data Scientist                                     Data Scientist
# 4           Data Scientist                                     Data Scientist
# 5           Data Scientist                                     Data Scientist
# 6           Data Scientist                                     Data Scientist
# 7           Data Scientist                                     Data Scientist
# 8           Data Scientist                                     Data Scientist
# 9           Data Scientist                                     Data Scientist
# 10          Data Scientist                                     Data Scientist
# 11          Data Scientist                                     Data Scientist
# 12          Data Scientist                                     Data Scientist
# 13          Data Scientist                                     Data Scientist
# 14          Data Scientist                                     Data Scientist
# 15          Data Scientist                                     Data Scientist
# 16          Data Scientist                                     Data Scientist
# 17          Data Scientist                                     Data Scientist
# 18          Data Scientist                                     Data Scientist
# 19          Data Scientist                                Lead Data Scientist
# 20          Data Scientist                              Senior Data Scientist
# 21          Data Scientist                              Senior Data Scientist
# 22          Data Scientist                              Senior Data Scientist
# 23          Data Scientist                              Senior Data Scientist
# 24          Data Scientist                                 Sr. Data Scientist
# 25          Data Scientist                              Senior Data Scientist
# 26          Data Scientist                              Senior Data Scientist
# 27          Data Scientist                              Senior Data Scientist
# 28          Data Scientist              Data Scientist (Quantitative Finance)
# 29          Data Scientist              Data Scientist (Quantitative Finance)
# ..                     ...                                                ...
# 486  Business Intelligence                 Technical Customer Success Manager
# 487  Business Intelligence                      Oracle Applications Developer
# 488  Business Intelligence                              Director of Analytics
# 489  Business Intelligence           Director of Delivery - Retail/E-Commerce
# 490  Business Intelligence          Solutions Architect - Excel, SQL, Tableau
# 491  Business Intelligence                 JD Edwards EnterpriseOne Developer
# 492  Business Intelligence                     Software Developer (SSIS/SSRS)
# 493  Business Intelligence                   Senior Product Marketing Manager
# 494  Business Intelligence             Lead Solutions Architect ($100k-$150k)
# 495  Business Intelligence                              Information Architect
# 496  Business Intelligence                 JD Edwards EnterpriseOne Developer
# 497  Business Intelligence                           Lead Solutions Architect
# 498  Business Intelligence                 JD Edwards EnterpriseOne Developer
# 499  Business Intelligence                             Senior Product Manager
# 500  Business Intelligence     SharePoint Developer (Applications Management)
# 501  Business Intelligence                                Microsoft Developer
# 502  Business Intelligence  JD Edwards Enterprise One 9.1 Specialist - Con...
# 503  Business Intelligence  Developer/Project Manager with SharePoint expe...
# 504  Business Intelligence                                 Accounting Manager
# 505  Business Intelligence                                  Financial Analyst
# 506  Business Intelligence                                 Database Architect
# 507  Business Intelligence           Lead Java Engineer - SOA, Micro-Services
# 508  Business Intelligence                  Sr Back-End Engineer - Java, SaaS
# 509  Business Intelligence  Lead Platform Engineer/Architect - SOA, Micro-...
# 510  Business Intelligence      Senior Full Stack Developer - ASP.NET MVC, C#
# 511  Business Intelligence                   Machine Learning Evangelist - Ai
# 512  Business Intelligence                Director of Market Development - Ai
# 513  Business Intelligence                 Ai Software Executive - Evangelist
# 514  Business Intelligence                   Senior Product Marketing Manager
# 515  Business Intelligence  Sales Representative - Software / Mobile Solut...
#
#                                            Description  \
# 0    Are you a Data Scientist who has machine learn...
# 1    If you are a Data Scientist with 4+ years data...
# 2    If you are a Data Scientist with experience, p...
# 3    If you are a Data Scientist who enjoys buildin...
# 4    If you are a Data Scientist with experience, p...
# 5    If you are a Data Scientist who has Python and...
# 6    If you are a Data Scientist with experience, p...
# 7    If you are a Data Scientist who enjoys develop...
# 8    Data Scientist - data mining, data sets, stati...
# 9    Data Scientist - Machine Learning, Python, Tab...
# 10   Data Scientist - SouthbayWe are creating a b2b...
# 11   If you are a Data Scientist with experience, p...
# 12   If you are a Data Scientist with 3+ years expe...
# 13   If you are a Data Scientist with a track recor...
# 14   We are a rapidly growing, privately held compa...
# 15   If you are a Data Scientist with experience, p...
# 16   If you are a Data Scientist with a track recor...
# 17   Based about 15 minutes outside of Boston(Newto...
# 18   Based in San Jose, CA and with teams internati...
# 19   Are you a Lead Data Scientist who has machine ...
# 20   If you are a Senior Data Scientist with strong...
# 21   This is a very unique Data Science opportunity...
# 22   This is a very unique Data Science opportunity...
# 23   San Jose, CA, US- RELOCATION INCLUDED! Your ap...
# 24   Located in beautiful Berkeley, CA, we have a p...
# 25   This is a very unique Data Science opportunity...
# 26   Are you attracted to a role which is part teac...
# 27   Are you attracted to a role which is part teac...
# 28   If you are a Data Scientist with experience in...
# 29   If you are a Data Scientist with experience in...
# ..                                                 ...
# 486  If you are a Customer Success Manager with exp...
# 487  If you are a Oracle Applications Developer, re...
# 488  If you are a Director of Analytics with experi...
# 489  If you are a Director of Delivery - Retail/E-C...
# 490  Keep in mind that if you fill out our 5 minute...
# 491  If you are a JD Edwards EnterpriseOne Develope...
# 492  If you are a Software Developer SSRS/SSIS with...
# 493  If you are a Senior Product Marketing Manager ...
# 494  If you are a Solutions Architect with experien...
# 495  If you are an Information Architect with exper...
# 496  If you are a JD Edwards EnterpriseOne Develope...
# 497  If you are a Solutions Architect with experien...
# 498  If you are a JD Edwards EnterpriseOne Develope...
# 499  Based in Austin, we are a revolutionary cognit...
# 500  We are a diversified media company owning publ...
# 501  We are a diversified media company owning publ...
# 502  If you are a JD Edwards Enterprise One 9.1 spe...
# 503  We are a diversified media company owning publ...
# 504  Sick of working in the grind of public account...
# 505  Job title:  Financial AnalystLocation:  405 FW...
# 506  If you are a Database Architect with experienc...
# 507  Located in beautiful Palo Alto, CA we are look...
# 508  Located in beautiful Palo Alto, CA we are look...
# 509  Located in beautiful Palo Alto, CA we are look...
# 510  Are you a Senior Fullstack .NET Developer that...
# 511  If you are a Machine Learning Evangelist with ...
# 512  If you are a Machine Learning Evangelist with ...
# 513  If you are a Ai Software Executive/ Evangelist...
# 514  If you are a Product Marketing Manager with en...
# 515  If you are a Software Sales Representative who...
#
#                                                 Skills              Location  \
# 0    Statistics, Machine Learning, Applied Mathematics       Los Angeles, CA
# 1    Data Science, Machine Learning, R, Python, SQL...     San Francisco, CA
# 2    Statistics, Mathematics, Computer Science, Mac...    Woodland Hills, CA
# 3    Python, Java, SQL (BigQuery/Oracle and Hive), ...       Los Angeles, CA
# 4            R Language, Python, Datasets, SQL Queries            Austin, TX
# 5    Full Stack, Cassandra, ElasticSearch, Solr, Da...         Cambridge, MA
# 6    Machine Learning, Tensorflow, Statistical/Mach...          Bethesda, MD
# 7    Python, Java, SQL (BigQuery/Oracle and Hive), ...       Los Angeles, CA
# 8    Data Mining, data sets, Statistical Modeling, ...  Plymouth Meeting, PA
# 9    Machine Learning, Python, Tableau, Hadoop, R, ...           Trenton, NJ
# 10   Data Science, Machine Learning, Python, scalab...          Campbell, CA
# 11    Machine Learning, Hadoop, Data Mining, R, Python     San Francisco, CA
# 12   econometric modeling, Statistical Modeling, Qu...         Pineville, NC
# 13   Data Mining, SAS, Tableau, R, Python, SQL, Dat...     New York City, NY
# 14    Data Science Experience, numpy, Machine Learning           Calgary, AB
# 15   Machine Learning, Python, R, SQL, Data Mining,...        Costa Mesa, CA
# 16   Data Mining, SAS, Tableau, R, Python, SQL, Dat...     New York City, NY
# 17            Machine Learning, Python, NLP Frameworks            Newton, MA
# 18   Data Science, Machine Learning, Natural Langua...          San Jose, CA
# 19       Machine Learning, Python, Applied Mathematics       Los Angeles, CA
# 20   Java, Hadoop, Python, NoSQL, AWS, Machine Lear...         San Mateo, CA
# 21   Data Science, Python, scikit.learn, Virtual En...     San Francisco, CA
# 22   Data Science, Python, scikit.learn, Virtual En...     San Francisco, CA
# 23   Data Science, Applied Research, Hadoop/MapRedu...          San Jose, CA
# 24   Python/R/Julia, Formulating metrics for optimi...          Berkeley, CA
# 25   Data Science, Python, scikit.learn, Virtual En...     San Francisco, CA
# 26   Data Science, Python, scikit.learn, Virtual En...     San Francisco, CA
# 27   Data Science, Python, scikit.learn, Bayesian I...           Chicago, IL
# 28   Python, Machine Learning, neural networks, Ris...     New York City, NY
# 29   Python, Machine Learning, neural networks, Ris...     New York City, NY
# ..                                                 ...                   ...
# 486  Customer Success Experience, Customer Renewals...     New York City, NY
# 487  Oracle, Oracle E-Business Suite, Oracle Forms,...         San Diego, CA
# 488  SQL, Python, R, Statistics, Analytics, E-Comme...     San Francisco, CA
# 489  Delivery, Retail, E-Commerce, client-facing, D...          Milpitas, CA
# 490  Excel, Power BI, Tableau, .NET, Java, Pre-Sale...            Peoria, IL
# 491  JD Edwards Enterprise One, Sales and Distribut...      White Plains, NY
# 492  ETL, SQL, C#, .NET, BI, T-SQL, Ssis, Ssrs, GIT...          Portland, ME
# 493  Product Marketing, Product Manager, Business i...     San Francisco, CA
# 494  Java, J2EE, Apache Storm, Kafka, ElasticSearch...           Houston, TX
# 495  Information Management, Data Analysis, Busines...       Saint Louis, MO
# 496  JD Edwards Enterprise One, Sales and Distribut...      White Plains, NY
# 497  Java, J2EE, Apache Storm, Kafka, ElasticSearch...     Missouri City, TX
# 498  JD Edwards Enterprise One, Sales and Distribut...      White Plains, NY
# 499  Product Management, Enterprise B2B Platforms, ...            Austin, TX
# 500  SharePoint, .NET, SDLC, Power BI, Microsoft Te...        South Bend, IN
# 501  SharePoint, .NET, SDLC, Power BI, Microsoft Te...        South Bend, IN
# 502  JD Edwards Enterprise One 9.1, OneView, ASP.NE...        Torrington, CT
# 503  SharePoint, .NET, Power BI, Microsoft Teams, M...        South Bend, IN
# 504  Managing Accountants, Advanced Excel Skills, R...            Irvine, CA
# 505  Financial Analysis, Financial Modeling, Budget...         Santa Ana, CA
# 506                     SQL, Database Architect, MySQL      Redwood City, CA
# 507  SaaS, Service-Oriented Architecture, micro-ser...         Palo Alto, CA
# 508  Java, SaaS, JavaScript, HTML/CSS, Spring, Boot...         Palo Alto, CA
# 509  SaaS, Service-Oriented Architecture, micro-ser...         Palo Alto, CA
# 510    ASP.NET MVC, C#, JavaScript, WCF, RESTful API's      Santa Monica, CA
# 511  AI, Marketing, Strategic Partnerships, Busines...         San Mateo, CA
# 512  AI, Marketing, Strategic Partnerships, Busines...         San Mateo, CA
# 513  AI, Marketing, Strategic Partnerships, Busines...         San Mateo, CA
# 514  Product Marketing, Enterprise Software, RPA Ro...            Irvine, CA
# 515  Sales Representative, Business Development, So...     New York City, NY
#
#                Cities States   Latitude   Longitude Min_Salary Max_Salary  \
# 0         Los Angeles     CA  34.052234 -118.243685     100000     200000
# 1       San Francisco     CA  37.774929 -122.419415     110000     175000
# 2      Woodland Hills     CA  34.165357 -118.608975    Unknown    Unknown
# 3         Los Angeles     CA  34.052234 -118.243685     120000     160000
# 4              Austin     TX  30.267153  -97.743061    Unknown    Unknown
# 5           Cambridge     MA  42.373616  -71.109733     110000     150000
# 6            Bethesda     MD  38.984652  -77.094709     100000     120000
# 7         Los Angeles     CA  34.052234 -118.243685     120000     160000
# 8    Plymouth Meeting     PA  40.102332  -75.274347     120000     160000
# 9             Trenton     NJ  40.220582  -74.759717     130000     150000
# 10           Campbell     CA  37.287165 -121.949957    Unknown    Unknown
# 11      San Francisco     CA  37.774929 -122.419415     120000     175000
# 12          Pineville     NC  35.083201  -80.892296    Unknown    Unknown
# 13      New York City     NY  40.712775  -74.005973     100000     130000
# 14            Calgary     AB  51.048615 -114.070846    Unknown    Unknown
# 15         Costa Mesa     CA  33.641216 -117.918822    Unknown    Unknown
# 16      New York City     NY  40.712775  -74.005973     100000     140000
# 17             Newton     MA  42.337041  -71.209221    Unknown    Unknown
# 18           San Jose     CA  37.338208 -121.886329     120000     160000
# 19        Los Angeles     CA  34.052234 -118.243685     150000     200000
# 20          San Mateo     CA  37.562992 -122.325525     175000     225000
# 21      San Francisco     CA  37.774929 -122.419415     100000     160000
# 22      San Francisco     CA  37.774929 -122.419415     100000     160000
# 23           San Jose     CA  37.338208 -121.886329    Unknown    Unknown
# 24           Berkeley     CA  37.871593 -122.272747    Unknown    Unknown
# 25      San Francisco     CA  37.774929 -122.419415     100000     160000
# 26      San Francisco     CA  37.774929 -122.419415     100000     160000
# 27            Chicago     IL  41.878114  -87.629798     100000     160000
# 28      New York City     NY  40.712775  -74.005973     120000     250000
# 29      New York City     NY  40.712775  -74.005973     120000     160000
# ..                ...    ...        ...         ...        ...        ...
# 486     New York City     NY  40.712775  -74.005973      75000      90000
# 487         San Diego     CA  32.715738 -117.161084    Unknown    Unknown
# 488     San Francisco     CA  37.774929 -122.419415     140000     200000
# 489          Milpitas     CA  37.432334 -121.899574     175000     200000
# 490            Peoria     IL  40.693649  -89.588986      75000      85000
# 491      White Plains     NY  41.033986  -73.762910    Unknown    Unknown
# 492          Portland     ME  43.659099  -70.256819      70000      90000
# 493     San Francisco     CA  37.774929 -122.419415     140000     200000
# 494           Houston     TX  29.760427  -95.369803     100000     150000
# 495       Saint Louis     MO  38.627003  -90.199404      90000     130000
# 496      White Plains     NY  41.033986  -73.762910    Unknown    Unknown
# 497     Missouri City     TX  29.618567  -95.537722     100000     150000
# 498      White Plains     NY  41.033986  -73.762910    Unknown    Unknown
# 499            Austin     TX  30.267153  -97.743061    Unknown    Unknown
# 500        South Bend     IN  41.676355  -86.251990      80000     100000
# 501        South Bend     IN  41.676355  -86.251990      80000     100000
# 502        Torrington     CT  41.800305  -73.121172     110000     150000
# 503        South Bend     IN  41.676355  -86.251990      80000     110000
# 504            Irvine     CA  33.684567 -117.826505    Unknown    Unknown
# 505         Santa Ana     CA  33.745472 -117.867653      70000      90000
# 506      Redwood City     CA  37.485215 -122.236355    Unknown    Unknown
# 507         Palo Alto     CA  37.441883 -122.143019     175000     200000
# 508         Palo Alto     CA  37.441883 -122.143019     150000     175000
# 509         Palo Alto     CA  37.441883 -122.143019     175000     200000
# 510      Santa Monica     CA  34.019454 -118.491191     110000     160000
# 511         San Mateo     CA  37.562992 -122.325525     200000     250000
# 512         San Mateo     CA  37.562992 -122.325525     200000     250000
# 513         San Mateo     CA  37.562992 -122.325525     200000     250000
# 514            Irvine     CA  33.684567 -117.826505     120000     140000
# 515     New York City     NY  40.712775  -74.005973      60000     160000
#
#     Mean_Salary                                                URL
# 0        150000  https://www.cybercoders.com/data-scientist-job...
# 1        142500  https://www.cybercoders.com/data-scientist-job...
# 2       Unknown  https://www.cybercoders.com/data-scientist-job...
# 3        140000  https://www.cybercoders.com/data-scientist-job...
# 4       Unknown  https://www.cybercoders.com/data-scientist-job...
# 5        130000  https://www.cybercoders.com/data-scientist-job...
# 6        110000  https://www.cybercoders.com/data-scientist-job...
# 7        140000  https://www.cybercoders.com/data-scientist-job...
# 8        140000  https://www.cybercoders.com/data-scientist-job...
# 9        140000  https://www.cybercoders.com/data-scientist-job...
# 10      Unknown  https://www.cybercoders.com/data-scientist-job...
# 11       147500  https://www.cybercoders.com/data-scientist-job...
# 12      Unknown  https://www.cybercoders.com/data-scientist-job...
# 13       115000  https://www.cybercoders.com/data-scientist-job...
# 14      Unknown  https://www.cybercoders.com/data-scientist-job...
# 15      Unknown  https://www.cybercoders.com/data-scientist-job...
# 16       120000  https://www.cybercoders.com/data-scientist-job...
# 17      Unknown  https://www.cybercoders.com/data-scientist-job...
# 18       140000  https://www.cybercoders.com/data-scientist-job...
# 19       175000  https://www.cybercoders.com/lead-data-scientis...
# 20       200000  https://www.cybercoders.com/senior-data-scient...
# 21       130000  https://www.cybercoders.com/senior-data-scient...
# 22       130000  https://www.cybercoders.com/senior-data-scient...
# 23      Unknown  https://www.cybercoders.com/senior-data-scient...
# 24      Unknown  https://www.cybercoders.com/sr-data-scientist-...
# 25       130000  https://www.cybercoders.com/senior-data-scient...
# 26       130000  https://www.cybercoders.com/senior-data-scient...
# 27       130000  https://www.cybercoders.com/senior-data-scient...
# 28       185000  https://www.cybercoders.com/data-scientist-qua...
# 29       140000  https://www.cybercoders.com/data-scientist-qua...
# ..          ...                                                ...
# 486       82500  https://www.cybercoders.com/technical-customer...
# 487     Unknown  https://www.cybercoders.com/oracle-application...
# 488      170000  https://www.cybercoders.com/director-of-analyt...
# 489      187500  https://www.cybercoders.com/director-of-delive...
# 490       80000  https://www.cybercoders.com/solutions-architec...
# 491     Unknown  https://www.cybercoders.com/jd-edwards-enterpr...
# 492       80000  https://www.cybercoders.com/software-developer...
# 493      170000  https://www.cybercoders.com/senior-product-mar...
# 494      125000  https://www.cybercoders.com/lead-solutions-arc...
# 495      110000  https://www.cybercoders.com/information-archit...
# 496     Unknown  https://www.cybercoders.com/jd-edwards-enterpr...
# 497      125000  https://www.cybercoders.com/lead-solutions-arc...
# 498     Unknown  https://www.cybercoders.com/jd-edwards-enterpr...
# 499     Unknown  https://www.cybercoders.com/senior-product-man...
# 500       90000  https://www.cybercoders.com/sharepoint-develop...
# 501       90000  https://www.cybercoders.com/microsoft-develope...
# 502      130000  https://www.cybercoders.com/jd-edwards-enterpr...
# 503       95000  https://www.cybercoders.com/developer-project-...
# 504     Unknown  https://www.cybercoders.com/accounting-manager...
# 505       80000  https://www.cybercoders.com/financial-analyst-...
# 506     Unknown  https://www.cybercoders.com/database-architect...
# 507      187500  https://www.cybercoders.com/lead-java-engineer...
# 508      162500  https://www.cybercoders.com/sr-back-end-engine...
# 509      187500  https://www.cybercoders.com/lead-platform-engi...
# 510      135000  https://www.cybercoders.com/senior-full-stack-...
# 511      225000  https://www.cybercoders.com/machine-learning-e...
# 512      225000  https://www.cybercoders.com/director-of-market...
# 513      225000  https://www.cybercoders.com/ai-software-execut...
# 514      130000  https://www.cybercoders.com/senior-product-mar...
# 515      110000  https://www.cybercoders.com/sales-representati...
#
# [516 rows x 13 columns]

# %%
# copy cleaned up jobs_data
master_data = jobs_scrub.copy()

# dataframe for data scientist
data_scientist_df = master_data.copy()
data_scientist_df = data_scientist_df[data_scientist_df['Search'].str.contains('Data Scientist')]
data_scientist_df = data_scientist_df.reset_index(drop = True)

# dataframe for data engineer
data_engineer_df = master_data.copy()
data_engineer_df = data_engineer_df[data_engineer_df['Search'].str.contains('Data Engineer')]
data_engineer_df = data_engineer_df.reset_index(drop = True)

# dataframe for data analyst
data_analyst_df = master_data.copy()
data_analyst_df = data_analyst_df[data_analyst_df['Search'].str.contains('Data Analyst')]
data_analyst_df = data_analyst_df.reset_index(drop = True)

# dataframe for business intelligence
business_intelligence_df = master_data.copy()
business_intelligence_df = business_intelligence_df[business_intelligence_df['Search'].str.contains('Business Intelligence')]
business_intelligence_df = business_intelligence_df.reset_index(drop = True)

# %%
w4 = '/Users/tmm/Documents/GitHub/STA160-Project/STA160-Jobs-Market-Project/Data'
os.chdir(w4)

master_data.to_csv('jobs_data.csv',index = False)
data_scientist_df.to_csv('data_scientist_data.csv', index = False)
data_engineer_df.to_csv('data_engineer_data.csv', index = False)
data_analyst_df.to_csv('data_analyst_data.csv', index = False)
business_intelligence_df.to_csv('BI_data.csv', index = False)

master_data_out = open('jobs_data.pickle', 'wb')
pickle.dump(master_data, master_data_out)
master_data_out.close()

data_scientist_out = open('data_scientist_data.pickle', 'wb')
pickle.dump(data_scientist_df, data_scientist_out)
data_scientist_out.close()

data_engineer_out = open('data_engineer_data.pickle', 'wb')
pickle.dump(data_engineer_df, data_engineer_out)
data_engineer_out.close()

data_analyst_out = open('data_analyst_data.pickle', 'wb')
pickle.dump(data_analyst_df, data_analyst_out)
data_analyst_out.close()

BI_out = open('BI_data.pickle', 'wb')
pickle.dump(business_intelligence_df, BI_out)
BI_out.close()
