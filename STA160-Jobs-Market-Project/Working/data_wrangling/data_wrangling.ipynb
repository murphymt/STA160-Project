# %%
import os
import pickle
import pandas as pd

wd2 = "/Users/tmm/Documents/GitHub/STA160-Project/STA160-Jobs-Market-Project/Working/data"
os.chdir(wd2)

jobs_scrub_in = open('raw_jobs_data.pickle', 'rb')
jobs_scrub = pickle.load(jobs_scrub_in)


jobs_scrub.columns = ['Search','Title','Description', 'Skills', 'Location', 'Latitude', 'Longitude', 'Salary', 'URL']

wd3 = "/Users/tmm/Documents/GitHub/STA160-Project/STA160-Jobs-Market-Project/Working/data_wrangling"
os.chdir(wd3)

# %%
def skills_clean(jobs_scrub, field):
    """
    (Purpose)
    Cleans up the skills for each listing. The raw data has 'Preferred Skills', '\r', and \n'
    that need to be removed in order to have a cleaner format. 
    
    (Arguments)
    field : Skills
    
    (Returns)
    skills : list of scrubbed skills
    
    """
    nrows, ncols = jobs_scrub.shape
    
    removals1 = ['Preferred Skills', '\r', '\n']
    for i in range(nrows):
        for j in removals1:
            holder1 = jobs_scrub[field][i].replace(j,'')
            jobs_scrub.loc[i,field] = holder1
        #jobs_scrub.loc[i,field] = jobs_scrub.loc[i,field].split('  ')
    
    skills_split = lambda jobs_scrub : jobs_scrub[field].split('  ')
    jobs_scrub[field] = jobs_scrub.apply(skills_split, axis = 1)
    
    none_removal = lambda jobs_scrub : list(filter(None, jobs_scrub[field]))
    jobs_scrub[field] = jobs_scrub.apply(none_removal, axis = 1)
    
    jobs_scrub[field] = jobs_scrub[field].apply(lambda jobs_scrub: ', '.join(map(str, jobs_scrub)))
    
    return jobs_scrub[field]

# %%
def description_scrub(jobs_scrub, field):
    """
    (Purpose)
    Cleans up the description for each listing. The raw data has '*', '\r', \n', and 
    'Applicants must be authorized to work in the U.S.' that need to be removed in order 
    to have a cleaner format. 
    
    (Arguments)
    field : Description
        
    (Returns)
    description : list of scrubbed descriptions
    
    """
    nrows, ncols = jobs_scrub.shape
    
    removals = ['*','\r','\n','Applicants must be authorized to work in the U.S.']
    for i in range(nrows):
        for j in removals:
            holder = jobs_scrub[field][i].replace(j,'')
            jobs_scrub.loc[i,field] = holder
    return jobs_scrub[field]

# %%
def location_clean(jobs_scrub, field):
    """
    (Purpose)
    Seperates the locations for each listing into city and states, which is a cleaner format for
    conducting analysis later on. 
    
    (Arguments)
    field : Location
    
    (Return)
    city : list of cities for job listings
    state : list of state for job listings
    
    """
    nrows, ncols = jobs_scrub.shape
    cities = []
    states = []
    for i in range(nrows):
        location_split = jobs_scrub[field][i].split(', ')
        cities.append(location_split[0])
        states.append(location_split[1])
    return cities, states

# %%
def salary_clean(jobs_scrub, field):
    """
    (Purpose)
    Cleans up the salary portion for each listing if there is data present. Seperates the salary
    estimates into a minimum and maximum salary estimate. Also, the format is converted into thousands
    and numeric. 
    
    (Arguments)
    field : Salary
    
    (Return)
    min_salary : list of minimum salary estimates
    max_salary : list of maximum salary estimates
    
    """
    nrows, ncols = jobs_scrub.shape
    min_salary = []
    max_salary = []
    mean_salary = []

        
    for i in range(nrows):
        for j in range(len(jobs_scrub[field][i])):
            if len(jobs_scrub[field][i][j]) >= 2:
                jobs_scrub[field][i][j] = jobs_scrub[field][i][j] + '000'
                jobs_scrub[field][i][j] = int(jobs_scrub[field][i][j])
    
    for i in range(nrows):
        if len(jobs_scrub[field][i]) == 0:
            jobs_scrub[field][i].append(0)
            jobs_scrub[field][i].append(0)
    
    for i in range(nrows):
        min_salary.append(jobs_scrub[field][i][0])
        max_salary.append(jobs_scrub[field][i][1])
        mean_salary.append((jobs_scrub[field][i][0] + jobs_scrub[field][i][1]) / 2)
        
    for i in range(nrows):
        if min_salary[i] == 0:
            min_salary[i] = 'Unknown'
        if max_salary[i] == 0:
            max_salary[i] = 'Unknown'
        if mean_salary[i] ==0:
            mean_salary[i] = 'Unknown'
            
            
    return min_salary, max_salary, mean_salary

# %%
description_list = description_scrub(jobs_scrub, 'Description')
skills_list = skills_clean(jobs_scrub, 'Skills')
locations_list = location_clean(jobs_scrub, 'Location')
wage_list = salary_clean(jobs_scrub, 'Salary')

jobs_scrub['Description'] = description_list
jobs_scrub['Skills'] = skills_list
jobs_scrub['Cities'] = locations_list[0]
jobs_scrub['States'] = locations_list[1]
jobs_scrub['Min_Salary'] = wage_list[0]
jobs_scrub['Max_Salary'] = wage_list[1]
jobs_scrub['Mean_Salary'] = wage_list[2]
jobs_scrub = jobs_scrub[jobs_scrub['Description'] != '']

jobs_scrub = jobs_scrub[['Search', 
                         'Title',
                         'Description',
                         'Skills',
                         'Location',
                         'Cities', 
                         'States', 
                         'Latitude', 
                         'Longitude', 
                         'Min_Salary', 
                         'Max_Salary', 
                         'Mean_Salary', 
                         'URL']]

# %%
jobs_scrub
# Out:
#                     Search                                              Title  \
# 0           Data Scientist                                     Data Scientist
# 1           Data Scientist                                     Data Scientist
# 2           Data Scientist                                     Data Scientist
# 3           Data Scientist                                     Data Scientist
# 4           Data Scientist                                     Data Scientist
# 5           Data Scientist                                     Data Scientist
# 6           Data Scientist                                     Data Scientist
# 7           Data Scientist                                     Data Scientist
# 8           Data Scientist                                     Data Scientist
# 9           Data Scientist                                     Data Scientist
# 10          Data Scientist                                     Data Scientist
# 11          Data Scientist                                     Data Scientist
# 12          Data Scientist                                     Data Scientist
# 13          Data Scientist                                     Data Scientist
# 14          Data Scientist                                     Data Scientist
# 15          Data Scientist                                     Data Scientist
# 16          Data Scientist                                     Data Scientist
# 17          Data Scientist                                     Data Scientist
# 18          Data Scientist                                     Data Scientist
# 19          Data Scientist                                     Data Scientist
# 20          Data Scientist                                Lead Data Scientist
# 21          Data Scientist                              Senior Data Scientist
# 22          Data Scientist                              Senior Data Scientist
# 23          Data Scientist                              Senior Data Scientist
# 24          Data Scientist                              Senior Data Scientist
# 25          Data Scientist                                 Sr. Data Scientist
# 26          Data Scientist                              Senior Data Scientist
# 27          Data Scientist                              Senior Data Scientist
# 28          Data Scientist                              Senior Data Scientist
# 29          Data Scientist              Data Scientist (Quantitative Finance)
# ..                     ...                                                ...
# 489  Business Intelligence                      Oracle Applications Developer
# 490  Business Intelligence                              Director of Analytics
# 491  Business Intelligence           Director of Delivery - Retail/E-Commerce
# 492  Business Intelligence          Solutions Architect - Excel, SQL, Tableau
# 493  Business Intelligence                 JD Edwards EnterpriseOne Developer
# 494  Business Intelligence                     Software Developer (SSIS/SSRS)
# 495  Business Intelligence                   Senior Product Marketing Manager
# 496  Business Intelligence             Lead Solutions Architect ($100k-$150k)
# 497  Business Intelligence                              Information Architect
# 498  Business Intelligence                 JD Edwards EnterpriseOne Developer
# 499  Business Intelligence                           Lead Solutions Architect
# 500  Business Intelligence                 JD Edwards EnterpriseOne Developer
# 501  Business Intelligence                   Lead Solutions Architect ($140k)
# 502  Business Intelligence                             Senior Product Manager
# 503  Business Intelligence     SharePoint Developer (Applications Management)
# 504  Business Intelligence                                Microsoft Developer
# 505  Business Intelligence  JD Edwards Enterprise One 9.1 Specialist - Con...
# 506  Business Intelligence  Developer/Project Manager with SharePoint expe...
# 507  Business Intelligence                                 Accounting Manager
# 508  Business Intelligence                                  Financial Analyst
# 509  Business Intelligence                                 Database Architect
# 510  Business Intelligence           Lead Java Engineer - SOA, Micro-Services
# 511  Business Intelligence                  Sr Back-End Engineer - Java, SaaS
# 512  Business Intelligence  Lead Platform Engineer/Architect - SOA, Micro-...
# 513  Business Intelligence      Senior Full Stack Developer - ASP.NET MVC, C#
# 514  Business Intelligence                   Machine Learning Evangelist - Ai
# 515  Business Intelligence                Director of Market Development - Ai
# 516  Business Intelligence                 Ai Software Executive - Evangelist
# 517  Business Intelligence                   Senior Product Marketing Manager
# 518  Business Intelligence  Sales Representative - Software / Mobile Solut...
#
#                                            Description  \
# 0    Are you a Data Scientist who has machine learn...
# 1    If you are a Data Scientist with 4+ years data...
# 2    If you are a Data Scientist with experience, p...
# 3    If you are a Data Scientist who enjoys buildin...
# 4    If you are a Data Scientist with experience, p...
# 5    If you are a Data Scientist who has Python and...
# 6    If you are a Data Scientist with experience, p...
# 7    If you are a Data Scientist who enjoys develop...
# 8    Data Scientist - data mining, data sets, stati...
# 9    Data Scientist - Machine Learning, Python, Tab...
# 10   Data Scientist - SouthbayWe are creating a b2b...
# 11   If you are a Data Scientist with experience, p...
# 12   If you are a Data Scientist with 3+ years expe...
# 13   If you are a Data Scientist with a track recor...
# 14   We are a rapidly growing, privately held compa...
# 15   If you are a Data Scientist with experience, p...
# 16   If you are a Data Scientist with a track recor...
# 17   Based about 15 minutes outside of Boston(Newto...
# 18   Based in San Jose, CA and with teams internati...
# 19   If you are a Data Scientist with experience, p...
# 20   Are you a Lead Data Scientist who has machine ...
# 21   If you are a Senior Data Scientist with strong...
# 22   This is a very unique Data Science opportunity...
# 23   This is a very unique Data Science opportunity...
# 24   San Jose, CA, US- RELOCATION INCLUDED! Your ap...
# 25   Located in beautiful Berkeley, CA, we have a p...
# 26   This is a very unique Data Science opportunity...
# 27   Are you attracted to a role which is part teac...
# 28   Are you attracted to a role which is part teac...
# 29   If you are a Data Scientist with experience in...
# ..                                                 ...
# 489  If you are a Oracle Applications Developer, re...
# 490  If you are a Director of Analytics with experi...
# 491  If you are a Director of Delivery - Retail/E-C...
# 492  Keep in mind that if you fill out our 5 minute...
# 493  If you are a JD Edwards EnterpriseOne Develope...
# 494  If you are a Software Developer SSRS/SSIS with...
# 495  If you are a Senior Product Marketing Manager ...
# 496  If you are a Solutions Architect with experien...
# 497  If you are an Information Architect with exper...
# 498  If you are a JD Edwards EnterpriseOne Develope...
# 499  If you are a Solutions Architect with experien...
# 500  If you are a JD Edwards EnterpriseOne Develope...
# 501  If you are a Solutions Architect with experien...
# 502  Based in Austin, we are a revolutionary cognit...
# 503  We are a diversified media company owning publ...
# 504  We are a diversified media company owning publ...
# 505  If you are a JD Edwards Enterprise One 9.1 spe...
# 506  We are a diversified media company owning publ...
# 507  Sick of working in the grind of public account...
# 508  Job title:  Financial AnalystLocation:  405 FW...
# 509  If you are a Database Architect with experienc...
# 510  Located in beautiful Palo Alto, CA we are look...
# 511  Located in beautiful Palo Alto, CA we are look...
# 512  Located in beautiful Palo Alto, CA we are look...
# 513  Are you a Senior Fullstack .NET Developer that...
# 514  If you are a Machine Learning Evangelist with ...
# 515  If you are a Machine Learning Evangelist with ...
# 516  If you are a Ai Software Executive/ Evangelist...
# 517  If you are a Product Marketing Manager with en...
# 518  If you are a Software Sales Representative who...
#
#                                                 Skills              Location  \
# 0    Statistics, Machine Learning, Applied Mathematics       Los Angeles, CA
# 1    Data Science, Machine Learning, R, Python, SQL...     San Francisco, CA
# 2    Statistics, Mathematics, Computer Science, Mac...    Woodland Hills, CA
# 3    Python, Java, SQL (BigQuery/Oracle and Hive), ...       Los Angeles, CA
# 4            R Language, Python, Datasets, SQL Queries            Austin, TX
# 5    Full Stack, Cassandra, ElasticSearch, Solr, Da...         Cambridge, MA
# 6    Machine Learning, Tensorflow, Statistical/Mach...          Bethesda, MD
# 7    Python, Java, SQL (BigQuery/Oracle and Hive), ...       Los Angeles, CA
# 8    Data Mining, data sets, Statistical Modeling, ...  Plymouth Meeting, PA
# 9    Machine Learning, Python, Tableau, Hadoop, R, ...           Trenton, NJ
# 10   Data Science, Machine Learning, Python, scalab...          Campbell, CA
# 11    Machine Learning, Hadoop, Data Mining, R, Python     San Francisco, CA
# 12   econometric modeling, Statistical Modeling, Qu...         Pineville, NC
# 13   Data Mining, SAS, Tableau, R, Python, SQL, Dat...     New York City, NY
# 14    Data Science Experience, numpy, Machine Learning           Calgary, AB
# 15   Machine Learning, Python, R, SQL, Data Mining,...        Costa Mesa, CA
# 16   Data Mining, SAS, Tableau, R, Python, SQL, Dat...     New York City, NY
# 17            Machine Learning, Python, NLP Frameworks            Newton, MA
# 18   Data Science, Machine Learning, Natural Langua...          San Jose, CA
# 19   Machine Learning, Python, R, Data Mining, Data...          Grinnell, IA
# 20       Machine Learning, Python, Applied Mathematics       Los Angeles, CA
# 21   Java, Hadoop, Python, NoSQL, AWS, Machine Lear...         San Mateo, CA
# 22   Data Science, Python, scikit.learn, Virtual En...     San Francisco, CA
# 23   Data Science, Python, scikit.learn, Virtual En...     San Francisco, CA
# 24   Data Science, Applied Research, Hadoop/MapRedu...          San Jose, CA
# 25   Python/R/Julia, Formulating metrics for optimi...          Berkeley, CA
# 26   Data Science, Python, scikit.learn, Virtual En...     San Francisco, CA
# 27   Data Science, Python, scikit.learn, Virtual En...     San Francisco, CA
# 28   Data Science, Python, scikit.learn, Bayesian I...           Chicago, IL
# 29   Python, Machine Learning, neural networks, Ris...     New York City, NY
# ..                                                 ...                   ...
# 489  Oracle, Oracle E-Business Suite, Oracle Forms,...         San Diego, CA
# 490  SQL, Python, R, Statistics, Analytics, E-Comme...     San Francisco, CA
# 491  Delivery, Retail, E-Commerce, client-facing, D...          Milpitas, CA
# 492  Excel, Power BI, Tableau, .NET, Java, Pre-Sale...            Peoria, IL
# 493  JD Edwards Enterprise One, Sales and Distribut...      White Plains, NY
# 494  ETL, SQL, C#, .NET, BI, T-SQL, Ssis, Ssrs, GIT...          Portland, ME
# 495  Product Marketing, Product Manager, Business i...     San Francisco, CA
# 496  Java, J2EE, Apache Storm, Kafka, ElasticSearch...           Houston, TX
# 497  Information Management, Data Analysis, Busines...       Saint Louis, MO
# 498  JD Edwards Enterprise One, Sales and Distribut...      White Plains, NY
# 499  Java, J2EE, Apache Storm, Kafka, ElasticSearch...     Missouri City, TX
# 500  JD Edwards Enterprise One, Sales and Distribut...      White Plains, NY
# 501  Java, J2EE, Apache Storm, Kafka, ElasticSearch...              Katy, TX
# 502  Product Management, Enterprise B2B Platforms, ...            Austin, TX
# 503  SharePoint, .NET, SDLC, Power BI, Microsoft Te...        South Bend, IN
# 504  SharePoint, .NET, SDLC, Power BI, Microsoft Te...        South Bend, IN
# 505  JD Edwards Enterprise One 9.1, OneView, ASP.NE...        Torrington, CT
# 506  SharePoint, .NET, Power BI, Microsoft Teams, M...        South Bend, IN
# 507  Managing Accountants, Advanced Excel Skills, R...            Irvine, CA
# 508  Financial Analysis, Financial Modeling, Budget...         Santa Ana, CA
# 509                     SQL, Database Architect, MySQL      Redwood City, CA
# 510  SaaS, Service-Oriented Architecture, micro-ser...         Palo Alto, CA
# 511  Java, SaaS, JavaScript, HTML/CSS, Spring, Boot...         Palo Alto, CA
# 512  SaaS, Service-Oriented Architecture, micro-ser...         Palo Alto, CA
# 513    ASP.NET MVC, C#, JavaScript, WCF, RESTful API's      Santa Monica, CA
# 514  AI, Marketing, Strategic Partnerships, Busines...         San Mateo, CA
# 515  AI, Marketing, Strategic Partnerships, Busines...         San Mateo, CA
# 516  AI, Marketing, Strategic Partnerships, Busines...         San Mateo, CA
# 517  Product Marketing, Enterprise Software, RPA Ro...            Irvine, CA
# 518  Sales Representative, Business Development, So...     New York City, NY
#
#                Cities States   Latitude   Longitude Min_Salary Max_Salary  \
# 0         Los Angeles     CA  34.052234 -118.243685     100000     200000
# 1       San Francisco     CA  37.774929 -122.419415     110000     175000
# 2      Woodland Hills     CA  34.165357 -118.608975    Unknown    Unknown
# 3         Los Angeles     CA  34.052234 -118.243685     120000     160000
# 4              Austin     TX  30.267153  -97.743061    Unknown    Unknown
# 5           Cambridge     MA  42.373616  -71.109733     110000     150000
# 6            Bethesda     MD  38.984652  -77.094709     100000     120000
# 7         Los Angeles     CA  34.052234 -118.243685     120000     160000
# 8    Plymouth Meeting     PA  40.102332  -75.274347     120000     160000
# 9             Trenton     NJ  40.220582  -74.759717     130000     150000
# 10           Campbell     CA  37.287165 -121.949957    Unknown    Unknown
# 11      San Francisco     CA  37.774929 -122.419415     120000     175000
# 12          Pineville     NC  35.083201  -80.892296    Unknown    Unknown
# 13      New York City     NY  40.712775  -74.005973     100000     130000
# 14            Calgary     AB  51.048615 -114.070846    Unknown    Unknown
# 15         Costa Mesa     CA  33.641216 -117.918822    Unknown    Unknown
# 16      New York City     NY  40.712775  -74.005973     100000     140000
# 17             Newton     MA  42.337041  -71.209221    Unknown    Unknown
# 18           San Jose     CA  37.338208 -121.886329     120000     160000
# 19           Grinnell     IA  41.743409  -92.723246      70000      90000
# 20        Los Angeles     CA  34.052234 -118.243685     150000     200000
# 21          San Mateo     CA  37.562992 -122.325525     175000     225000
# 22      San Francisco     CA  37.774929 -122.419415     100000     160000
# 23      San Francisco     CA  37.774929 -122.419415     100000     160000
# 24           San Jose     CA  37.338208 -121.886329    Unknown    Unknown
# 25           Berkeley     CA  37.871593 -122.272747    Unknown    Unknown
# 26      San Francisco     CA  37.774929 -122.419415     100000     160000
# 27      San Francisco     CA  37.774929 -122.419415     100000     160000
# 28            Chicago     IL  41.878114  -87.629798     100000     160000
# 29      New York City     NY  40.712775  -74.005973     120000     250000
# ..                ...    ...        ...         ...        ...        ...
# 489         San Diego     CA  32.715738 -117.161084    Unknown    Unknown
# 490     San Francisco     CA  37.774929 -122.419415     140000     200000
# 491          Milpitas     CA  37.432334 -121.899574     175000     200000
# 492            Peoria     IL  40.693649  -89.588986      75000      85000
# 493      White Plains     NY  41.033986  -73.762910    Unknown    Unknown
# 494          Portland     ME  43.659099  -70.256819      70000      90000
# 495     San Francisco     CA  37.774929 -122.419415     140000     200000
# 496           Houston     TX  29.760427  -95.369803     100000     150000
# 497       Saint Louis     MO  38.627003  -90.199404      90000     130000
# 498      White Plains     NY  41.033986  -73.762910    Unknown    Unknown
# 499     Missouri City     TX  29.618567  -95.537722     100000     150000
# 500      White Plains     NY  41.033986  -73.762910    Unknown    Unknown
# 501              Katy     TX  29.785785  -95.824396     100000     150000
# 502            Austin     TX  30.267153  -97.743061    Unknown    Unknown
# 503        South Bend     IN  41.676355  -86.251990      80000     100000
# 504        South Bend     IN  41.676355  -86.251990      80000     100000
# 505        Torrington     CT  41.800305  -73.121172     110000     150000
# 506        South Bend     IN  41.676355  -86.251990      80000     110000
# 507            Irvine     CA  33.684567 -117.826505    Unknown    Unknown
# 508         Santa Ana     CA  33.745472 -117.867653      70000      90000
# 509      Redwood City     CA  37.485215 -122.236355    Unknown    Unknown
# 510         Palo Alto     CA  37.441883 -122.143019     175000     200000
# 511         Palo Alto     CA  37.441883 -122.143019     150000     175000
# 512         Palo Alto     CA  37.441883 -122.143019     175000     200000
# 513      Santa Monica     CA  34.019454 -118.491191     110000     160000
# 514         San Mateo     CA  37.562992 -122.325525     200000     250000
# 515         San Mateo     CA  37.562992 -122.325525     200000     250000
# 516         San Mateo     CA  37.562992 -122.325525     200000     250000
# 517            Irvine     CA  33.684567 -117.826505     120000     140000
# 518     New York City     NY  40.712775  -74.005973      60000     160000
#
#     Mean_Salary                                                URL
# 0        150000  https://www.cybercoders.com/data-scientist-job...
# 1        142500  https://www.cybercoders.com/data-scientist-job...
# 2       Unknown  https://www.cybercoders.com/data-scientist-job...
# 3        140000  https://www.cybercoders.com/data-scientist-job...
# 4       Unknown  https://www.cybercoders.com/data-scientist-job...
# 5        130000  https://www.cybercoders.com/data-scientist-job...
# 6        110000  https://www.cybercoders.com/data-scientist-job...
# 7        140000  https://www.cybercoders.com/data-scientist-job...
# 8        140000  https://www.cybercoders.com/data-scientist-job...
# 9        140000  https://www.cybercoders.com/data-scientist-job...
# 10      Unknown  https://www.cybercoders.com/data-scientist-job...
# 11       147500  https://www.cybercoders.com/data-scientist-job...
# 12      Unknown  https://www.cybercoders.com/data-scientist-job...
# 13       115000  https://www.cybercoders.com/data-scientist-job...
# 14      Unknown  https://www.cybercoders.com/data-scientist-job...
# 15      Unknown  https://www.cybercoders.com/data-scientist-job...
# 16       120000  https://www.cybercoders.com/data-scientist-job...
# 17      Unknown  https://www.cybercoders.com/data-scientist-job...
# 18       140000  https://www.cybercoders.com/data-scientist-job...
# 19        80000  https://www.cybercoders.com/data-scientist-job...
# 20       175000  https://www.cybercoders.com/lead-data-scientis...
# 21       200000  https://www.cybercoders.com/senior-data-scient...
# 22       130000  https://www.cybercoders.com/senior-data-scient...
# 23       130000  https://www.cybercoders.com/senior-data-scient...
# 24      Unknown  https://www.cybercoders.com/senior-data-scient...
# 25      Unknown  https://www.cybercoders.com/sr-data-scientist-...
# 26       130000  https://www.cybercoders.com/senior-data-scient...
# 27       130000  https://www.cybercoders.com/senior-data-scient...
# 28       130000  https://www.cybercoders.com/senior-data-scient...
# 29       185000  https://www.cybercoders.com/data-scientist-qua...
# ..          ...                                                ...
# 489     Unknown  https://www.cybercoders.com/oracle-application...
# 490      170000  https://www.cybercoders.com/director-of-analyt...
# 491      187500  https://www.cybercoders.com/director-of-delive...
# 492       80000  https://www.cybercoders.com/solutions-architec...
# 493     Unknown  https://www.cybercoders.com/jd-edwards-enterpr...
# 494       80000  https://www.cybercoders.com/software-developer...
# 495      170000  https://www.cybercoders.com/senior-product-mar...
# 496      125000  https://www.cybercoders.com/lead-solutions-arc...
# 497      110000  https://www.cybercoders.com/information-archit...
# 498     Unknown  https://www.cybercoders.com/jd-edwards-enterpr...
# 499      125000  https://www.cybercoders.com/lead-solutions-arc...
# 500     Unknown  https://www.cybercoders.com/jd-edwards-enterpr...
# 501      125000  https://www.cybercoders.com/lead-solutions-arc...
# 502     Unknown  https://www.cybercoders.com/senior-product-man...
# 503       90000  https://www.cybercoders.com/sharepoint-develop...
# 504       90000  https://www.cybercoders.com/microsoft-develope...
# 505      130000  https://www.cybercoders.com/jd-edwards-enterpr...
# 506       95000  https://www.cybercoders.com/developer-project-...
# 507     Unknown  https://www.cybercoders.com/accounting-manager...
# 508       80000  https://www.cybercoders.com/financial-analyst-...
# 509     Unknown  https://www.cybercoders.com/database-architect...
# 510      187500  https://www.cybercoders.com/lead-java-engineer...
# 511      162500  https://www.cybercoders.com/sr-back-end-engine...
# 512      187500  https://www.cybercoders.com/lead-platform-engi...
# 513      135000  https://www.cybercoders.com/senior-full-stack-...
# 514      225000  https://www.cybercoders.com/machine-learning-e...
# 515      225000  https://www.cybercoders.com/director-of-market...
# 516      225000  https://www.cybercoders.com/ai-software-execut...
# 517      130000  https://www.cybercoders.com/senior-product-mar...
# 518      110000  https://www.cybercoders.com/sales-representati...
#
# [519 rows x 13 columns]

# %%
# copy cleaned up jobs_data
master_data = jobs_scrub.copy()

# dataframe for data scientist
data_scientist_df = master_data.copy()
data_scientist_df = data_scientist_df[data_scientist_df['Search'].str.contains('Data Scientist')]
data_scientist_df = data_scientist_df.reset_index(drop = True)

# dataframe for data engineer
data_engineer_df = master_data.copy()
data_engineer_df = data_engineer_df[data_engineer_df['Search'].str.contains('Data Engineer')]
data_engineer_df = data_engineer_df.reset_index(drop = True)

# dataframe for data analyst
data_analyst_df = master_data.copy()
data_analyst_df = data_analyst_df[data_analyst_df['Search'].str.contains('Data Analyst')]
data_analyst_df = data_analyst_df.reset_index(drop = True)

# dataframe for business intelligence
business_intelligence_df = master_data.copy()
business_intelligence_df = business_intelligence_df[business_intelligence_df['Search'].str.contains('Business Intelligence')]
business_intelligence_df = business_intelligence_df.reset_index(drop = True)

# %%
w4 = '/Users/tmm/Documents/GitHub/STA160-Project/STA160-Jobs-Market-Project/Working/data'
os.chdir(w4)

master_data.to_csv('jobs_data.csv',index = False)
data_scientist_df.to_csv('data_scientist_data.csv', index = False)
data_engineer_df.to_csv('data_engineer_data.csv', index = False)
data_analyst_df.to_csv('data_analyst_data.csv', index = False)
business_intelligence_df.to_csv('BI_data.csv', index = False)

master_data_out = open('jobs_data.pickle', 'wb')
pickle.dump(master_data, master_data_out)
master_data_out.close()

data_scientist_out = open('data_scientist_data.pickle', 'wb')
pickle.dump(data_scientist_df, data_scientist_out)
data_scientist_out.close()

data_engineer_out = open('data_engineer_data.pickle', 'wb')
pickle.dump(data_engineer_df, data_engineer_out)
data_engineer_out.close()

data_analyst_out = open('data_analyst_data.pickle', 'wb')
pickle.dump(data_analyst_df, data_analyst_out)
data_analyst_out.close()

BI_out = open('BI_data.pickle', 'wb')
pickle.dump(business_intelligence_df, BI_out)
BI_out.close()
