# %%
import numpy as np
import pandas as pd
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import nltk
from nltk import word_tokenize
from nltk.util import ngrams
from collections import Counter

# %%
cd Desktop/
# Out:
# [WinError 2] The system cannot find the file specified: 'Desktop/'
# C:\Users\Hanying Li\Desktop

# %%
df = pd.read_csv("datascientist simplyhired.csv")

# %%
df
# Out:
#        Unnamed: 0                                          Job Title  \
# 0               0                         Data Scientist Entry Level
# 1               1                                     Data Scientist
# 2               2            Data Scientist - Defense & Intelligence
# 3               3                                     Data Scientist
# 4               4                                 COMPUTER SCIENTIST
# 5               5                        Data Scientist, Engineering
# 6               6  Data Scientist, Engineering Support Analytics,...
# 7               7                        Data Scientist, Engineering
# 8               8                        Data Scientist, Engineering
# 9               9                         Data Scientist (Corporate)
# 10             10                                     Data Scientist
# 11             11                                   Data Scientist I
# 12             12                                     Data Scientist
# ...

# %%
df = df.replace(np.nan, 'null', regex=True)

# %%
str = df['Job Salary']
newsalary = []
for i in range(len(df['Job Salary'])):
    s = re.findall('\d+,\d+', str[i] )
    if len(s)>1:
        a = int(re.sub(r",","",s[0]))
        b = int(re.sub(r",","",s[1]))
        salary = (a +b)/2
        newsalary.append(salary)
    else:
        newsalary.append(s)
    i +=1

# %%
newsalary
# Out:
# [94000.0,
#  155000.0,
#  130000.0,
#  145000.0,
#  106000.0,
#  105500.0,
#  135000.0,
#  103500.0,
#  107500.0,
#  75500.0,
#  ['170,000'],
#  96000.0,
#  125000.0,
#  73500.0,
#  [],
#  [],
#  [],
#  95500.0,
#  ['2,500'],
#  99000.0,
#  120000.0,
#  114000.0,
#  109500.0,
#  118000.0,
#  113000.0,
#  102500.0,
#  130000.0,
#  95000.0,
#  111500.0,
#  125000.0,
#  109000.0,
#  110000.0,
#  111500.0,
#  114500.0,
#  113000.0,
#  113000.0,
#  116500.0,
#  135000.0,
#  120000.0,
#  140000.0,
#  165000.0,
#  130000.0,
#  114000.0,
#  97000.0,
#  109000.0,
#  [],
#  170000.0,
#  150000.0,
#  ['160,000'],
#  101500.0,
#  89500.0,
#  130000.0,
#  61000.0,
#  160000.0,
#  120000.0,
#  113500.0,
#  155000.0,
#  165000.0,
#  160000.0,
#  [],
#  ['2,000'],
#  ['190,000'],
#  160000.0,
#  35000.0,
#  ['45,000'],
#  95000.0,
#  70000.0,
#  106000.0,
#  84000.0,
#  120000.0,
#  115000.0,
#  205000.0,
#  105000.0,
#  82500.0,
#  105500.0,
#  101000.0,
#  104000.0,
#  114500.0,
#  105000.0,
# ...

# %%
df['Job Salary'] = newsalary

# %%
df
# Out:
#        Unnamed: 0                                          Job Title  \
# 0               0                         Data Scientist Entry Level
# 1               1                                     Data Scientist
# 2               2            Data Scientist - Defense & Intelligence
# 3               3                                     Data Scientist
# 4               4                                 COMPUTER SCIENTIST
# 5               5                        Data Scientist, Engineering
# 6               6  Data Scientist, Engineering Support Analytics,...
# 7               7                        Data Scientist, Engineering
# 8               8                        Data Scientist, Engineering
# 9               9                         Data Scientist (Corporate)
# 10             10                                     Data Scientist
# 11             11                                   Data Scientist I
# 12             12                                     Data Scientist
# ...

# %%
wordnet_lemmatizer = WordNetLemmatizer()
alist = [line.rstrip() for line in open('stopwords.txt')]
stopword = stopwords.words('english') + alist

# %%
def my_preprocessing(s):
    s = s.lower() # downcase
    s = re.sub(r"\W"," ",s)
    s = re.sub(r"\d+"," ",s)
    s = re.sub(r"\s+",' ',s)
    return s

# %%
def my_tokenize(s):
    tokens = nltk.tokenize.word_tokenize(s) # split string into words (tokens)
    tokens = [t for t in tokens if len(t) > 2] # remove short words, they're probably not useful
    tokens = [wordnet_lemmatizer.lemmatize(t) for t in tokens] # put words into base form
    tokens = [t for t in tokens if t not in set(stopword)]# remove stopwords
    s = ' '.join(tokens)
    return s

# %%
newsnippets = []
for i in range(len(df["Snippets"])):
    new = my_preprocessing(df["Snippets"][i])
    finalnew = my_tokenize(new)
    i += 1
    newsnippets.append(finalnew)
    print (finalnew)
# Out:
# deep learning machine learning data data scientist influence intel doe business data driven decision time
# master degree applied math statistic machine learning computer science relevant subject
# machine learning predictive analytics data mining advanced analytics statistic workload prioritization operation research risk analysis streaming
# provides guidance direction related data research advanced analytics strategic data amp analytics staff
# resume relevant experience cover letter optional job title duty accomplishment employer name address
# relevant experience statistician computational biologist bioinformatician data scientist including deep expertise
# employ predictive analytics machine learning facilitate forecasting fast growing global support operation
# relevant experience statistician computational biologist bioinformatician data scientist including deep expertise
# ...

# %%
df["Snippets"] = newsnippets

# %%
df
# Out:
#        Unnamed: 0                                          Job Title  \
# 0               0                         Data Scientist Entry Level
# 1               1                                     Data Scientist
# 2               2            Data Scientist - Defense & Intelligence
# 3               3                                     Data Scientist
# 4               4                                 COMPUTER SCIENTIST
# 5               5                        Data Scientist, Engineering
# 6               6  Data Scientist, Engineering Support Analytics,...
# 7               7                        Data Scientist, Engineering
# 8               8                        Data Scientist, Engineering
# 9               9                         Data Scientist (Corporate)
# 10             10                                     Data Scientist
# 11             11                                   Data Scientist I
# 12             12                                     Data Scientist
# ...

# %%
import csv
df.to_csv('datascienClean.csv')

# %%
city= []
skill = []
salary = []
totalsala = []
totalskill = []
for loc in set(df["Location"]):
    city.append(loc)
    for i in range(len(df["Location"])):
        if df['Location'][i] == loc:
            salary.append(df["Job Salary"][i])
            skill.append(df["Snippets"][i])
            i +=1
    totalsala.append(salary)
    totalskill.append(skill)
    skill = []
    salary = []

# %%
dataframe = pd.DataFrame({'Location':city, 'Job Salary':totalsala, 'Skills':totalskill},columns = ['Location','Job Salary','Skills'])
dataframe
# Out:
#                               Location  \
# 0                     Lambertville, NJ
# 1                       Hagerstown, MD
# 2                         Monrovia, CA
# 3                          Oakland, CA
# 4                           Tustin, CA
# 5                     Pearl Harbor, HI
# 6                        Manitowoc, WI
# 7                       Minnetonka, MN
# 8                         Brooklyn, NY
# 9                       Swiftwater, PA
# 10                   New Brunswick, NJ
# 11                       Nashville, TN
# 12                        Franklin, TN
# 13                  South Portland, ME
# 14                     Albuquerque, NM
# 15                           Eagle, ID
# 16                          Draper, UT
# 17                      Pine Brook, NJ
# 18                         Socorro, NM
# 19                 Shawnee Mission, KS
# 20                          Natick, MA
# 21                        Bethesda, MD
# 22                      North Carolina
# ...

# %%
countword = []
for i in range(480):
    word2count = {}
    comb = ' '.join(dataframe["Skills"][i])
    words = nltk.word_tokenize(comb)
    for word in words:
        if word not in word2count.keys():
            word2count[word]=1
        else:
            word2count[word]+=1
    countword.append(word2count)
    i += 1

# %%
dataframe['Countword'] = countword

# %%
numbers = []
for i in range(len(dataframe["Job Salary"])):
    num = len(dataframe["Job Salary"][i])
    numbers.append(num)
    i +=1

dataframe["Numbers"] = numbers

# %%
cd sta160Project/
# Out:
# C:\Users\Hanying Li\Desktop\sta160Project

# %%
df = pd.read_csv("datasciCleaned.csv")

# %%
df["Numbers"] = numbers

# %%
from pygeocoder import Geocoder
import pandas as pd
import numpy as np
# Out:
# Counter({('business', 'data'): (1, 0),
#          ('data', 'data'): 1,
#          ('data', 'driven'): 1,
#          ('data', 'scientist'): 1,
#          ('decision', 'time'): 1,
#          ('deep', 'learning'): 1,
#          ('doe', 'business'): 1,
#          ('driven', 'decision'): 1,
#          ('influence', 'intel'): 1,
#          ('intel', 'doe'): 1,
#          ('learning', 'data'): 1,
#          ('learning', 'machine'): 1,
#          ('machine', 'learning'): 1,
#          ('scientist', 'influence'): 1,
#          1: (1, 0)})

# %%
import requests
lon = []
lat = []
for i in range(480):
    address = dataframe["Location"][i]
    api_key = "AIzaSyBu6BJ2BO7GHPPDnPKcowykaNy67ib5CRE"
    api_response = requests.get('https://maps.googleapis.com/maps/api/geocode/json?address={0}&key={1}'.format(address, api_key))
    api_response_dict = api_response.json()
    i +=1
    if api_response_dict['status'] == 'OK':
        latitude = api_response_dict['results'][0]['geometry']['location']['lat']
        longitude = api_response_dict['results'][0]['geometry']['location']['lng']
        lon.append(longitude)
        lat.append(latitude)
    print(latitude,longitude)
# Out:
# 42.6525793 -73.7562317
# 40.8262101 -73.502068
# 33.7414085 -118.1047682
# 45.2998418 -122.7737062
# 39.7589478 -84.1916069
# 37.4315734 -78.6568942
# 40.1853862 -75.2276756
# 32.7459645 -96.99778459999999
# 44.9530215 -92.9952153
# 38.984652 -77.0947092
# 36.6634467 -87.47739020000002
# 38.5449065 -121.7405167
# 26.3683064 -80.1289321
# 35.823483 -78.8255621
# 40.7066174 -74.5493284
# 35.8991678 -78.86364019999999
# 40.5246711 -111.8638226
# 47.3309328 -122.3604013
# 37.5585465 -122.2710788
# 47.1342432 -122.4857321
# 38.71887160000001 -77.15426839999999
# 35.9250637 -86.8688899
# 29.6516344 -82.32482619999999
# 39.9205411 -105.0866504
# 35.6869752 -105.937799
# 43.6770252 -70.3711617
# 42.21420639999999 -83.14992389999999
# 42.3736158 -71.10973349999999
# 32.735687 -97.10806559999999
# 38.9692771 -77.07886669999999
# 42.8125913 -70.87727509999999
# 41.8239891 -71.4128343
# 45.5230622 -122.6764815
# 40.1723141 -75.4927278
# 37.09024 -95.712891
# 45.6769979 -111.0429339
# ...

# %%
dataframe['lon']= lon
dataframe['lat']= lat

# %%
df.to_csv('datasciCleaned.csv')

# %%
#plotly.offline doesn't push your charts to the clouds
import plotly.offline as pyo
#allows us to create the Data and Figure objects
from plotly.graph_objs import *
#plotly.plotly pushes your charts to the cloud  
import plotly.plotly as py

#lets us see the charts in an iPython Notebook#lets u 
pyo.offline.init_notebook_mode() # run at the start of every ipython

# %%
location = list(dataframe["Location"])
location
# Out:
# ['Albany, NY',
#  'Syosset, NY',
#  'Seal Beach, CA',
#  'Wilsonville, OR',
#  'Dayton, OH',
#  'Virginia',
#  'Spring House, PA',
#  'Grand Prairie, TX',
#  'Maplewood, MN',
#  'Bethesda, MD',
#  'Fort Campbell, KY',
#  'Davis, CA',
#  'Boca Raton, FL',
#  'Morrisville, NC',
#  'Basking Ridge, NJ',
#  'Raleigh-Durham, NC',
#  'Draper, UT',
#  'Adelaide, WA',
#  'Foster City, CA',
#  'Joint Base Lewis McChord, WA',
#  'Fort Belvoir, VA',
#  'Franklin, TN',
#  'Gainesville, FL',
#  'Broomfield, CO',
#  'Santa Fe, NM',
#  'Westbrook, ME',
#  'Wyandotte, MI',
#  'Cambridge, MA',
#  'Arlington, TX',
#  'Chevy Chase, MD',
#  'Newburyport, MA',
#  'Providence, RI',
#  'Portland, OR',
#  'Upper Providence, PA',
#  'United States',
#  'Bozeman, MT',
#  'Beavercreek, OH',
#  'Socorro, NM',
#  'Fort Washington, PA',
#  'Athens, GA',
#  'Boston, MA',
#  'Mill Valley, CA',
#  'Cold Spring Harbor, NY',
#  'Hanover, NH',
#  'Melbourne, FL',
#  'Westford, MA',
#  'Petaluma, CA',
#  'Dam Neck, VA',
# ...
